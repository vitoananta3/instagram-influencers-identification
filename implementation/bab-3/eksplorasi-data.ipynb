# %% [markdown]
# # BAB 3

# %% [markdown]
# ##### Import Libraries

# %%
import os
import ast
import json
from langdetect import detect, LangDetectException
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import random

# %% [markdown]
# ##### Paths

# %%
# dataset
post_info_path = '../../dataset/post_info.txt'
images_dir = '../../dataset/images'
json_dir = '../../dataset/json'
profiles_influencers_dir = '../../dataset/profiles_influencers'

# preprocessed data
missing_images_posts_path = '../../dataset/missing_images_posts.txt'
post_with_existing_images_info_path = '../../dataset/post_with_existing_images_info.txt'

missing_json_posts_path = '../../dataset/missing_json_posts.txt'
post_with_existing_images_and_json_info_path = '../../dataset/post_with_existing_images_and_json_info.txt'

missing_caption_posts_path = '../../dataset/missing_caption_posts.txt'
post_with_existing_images_json_and_caption_info_path = '../../dataset/post_with_existing_images_json_and_caption_info.txt'

missing_english_caption_posts_path = '../../dataset/missing_english_caption_posts.txt'
post_with_existing_images_json_caption_and_english_info_path = '../../dataset/post_with_existing_images_json_caption_and_english_info.txt'

contain_giveaway_caption_posts_path = '../../dataset/contain_giveaway_caption_posts.txt'
post_clean_info_path = '../../dataset/post_clean_info.txt'

influencers_list_path = '../../dataset/influencers_list_of_clean_data.csv'
influencers_list_clean_path = '../../dataset/influencers_list_clean.csv'
influencers_error_list_path = '../../dataset/influencers_error_list.txt'

# exploration data
exploration_data_dir = '../../dataset/results'

exploration_data_clean_dir = '../../dataset/clean'

exploration_data_clean_banget_dir = '../../inti/eda/clean-banget'

post_with_micro_influencer_info_path = '../../dataset/post_with_micro_influencer_info.txt'

post_with_micro_influencer_clean_info_path = '../../dataset/post_with_micro_influencer_clean_info.txt'

post_sampled_info_path = '../../dataset/post_sampled_info.txt'

post_13000_sampled_info_path = '../../dataset/post_13000_sampled_info.txt'

post_34000_sampled_info_path = '../../dataset/post_34000_sampled_info.txt'

post_34000_sampled_clean_info_path = '../../dataset/post_34000_sampled_clean_info.txt'

influencers_after_sampling_list_path = '../../dataset/influencers_after_sampling_list.csv'

influencers_13000_after_sampling_list_path = '../../dataset/influencers_13000_after_sampling_list.csv'

influencers_34000_after_sampling_list_path = '../../dataset/influencers_34000_after_sampling_list.csv'

influencers_34000_after_sampling_list_clean_path = '../../dataset/influencers_34000_after_sampling_list_clean.csv'

exploration_data_after_sampling_dir = '../../dataset/results-after-exploration'

exploration_13000_data_after_sampling_dir = '../../dataset/results-13000-after-exploration'

exploration_34000_data_after_sampling_dir = '../../dataset/results-34000-after-exploration'

exploration_34000_data_after_sampling_clean_dir = '../../inti/eda/clean-banget/after-sampling'

exploration_34000_data_after_sampling_clean_banget_dir = '../../inti/model-results/results-34000-after-exploration-clean-banget'

# %% [markdown]
# ##### Total posts **(raw from original dataset)**

# %%
def count_posts(file_path=post_info_path):
    count = 0
    with open(file_path, "r", encoding="utf-8") as f:
        for line in f:
            if line.strip():
                count += 1
    return count

# %%
total_posts_original = count_posts()
print(f"Total posts: {total_posts_original}")
# Out:
# Total posts: 1601074

# %% [markdown]
# ## Preprocessing Data

# %% [markdown]
# ##### Create and total posts with missing image(s)

# %%
def create_missing_images_posts_file(post_info_path, images_dir):
    missing_posts = []
    with open(post_info_path, "r", encoding="utf-8") as f:
        for line in f:
            if not line.strip():
                continue
            # Split row on tab and use the last column for image list
            columns = line.strip().split("\t")
            # Use ast.literal_eval to get a list of image names
            try:
                images = ast.literal_eval(columns[-1])
            except Exception:
                images = []
            missing = False
            for img in images:
                if img.lower().endswith('.jpg'):
                    image_path = os.path.join(images_dir, img)
                    if not os.path.exists(image_path):
                        missing = True
                        break
            if missing:
                missing_posts.append(line)

    # Write missing posts to file
    with open(missing_images_posts_path, "w", encoding="utf-8") as f_out:
        f_out.writelines(missing_posts)

# %%
# create_missing_images_posts_file(post_info_path, images_dir)

# %%
def count_total_posts_with_missing_images(file_path=missing_images_posts_path):
    return count_posts(file_path)

# %%
total_posts_with_missing_images = count_total_posts_with_missing_images()
print(f"Total posts with missing images: {total_posts_with_missing_images}")
# Out:
# Total posts with missing images: 814

# %% [markdown]
# ##### Create new **post info txt** file with no missing image(s)

# %%
def create_no_missing_images_post_info_file(post_info_path, missing_images_posts_path, post_with_existing_images_info_path):
    with open(missing_images_posts_path, "r", encoding="utf-8") as f_missing:
        missing_posts = set(line.strip() for line in f_missing)

    with open(post_info_path, "r", encoding="utf-8") as f_in, \
            open(post_with_existing_images_info_path, "w", encoding="utf-8") as f_out:

        row_number = 0
        for line in f_in:
            if line.strip() and line.strip() not in missing_posts:
                f_out.write(str(row_number) + line[line.find('\t'):])
                row_number += 1

# %%
# create_no_missing_images_post_info_file(post_info_path, missing_images_posts_path, post_with_existing_images_info_path)

# %% [markdown]
# ##### Total posts **(after removing posts with missing images)**

# %%
def count_post_with_existing_images(file_path=post_with_existing_images_info_path):
    return count_posts(file_path)

# %%
total_posts_with_existing_images = count_post_with_existing_images()
print(f"Total posts with existing images: {total_posts_with_existing_images}")
# Out:
# Total posts with existing images: 1600260

# %% [markdown]
# ##### Create and total posts with missing json file

# %%
def create_missing_json_posts_file(post_with_existing_images_info_path, json_dir, missing_json_posts_path):
    missing_json_posts = []
    with open(post_with_existing_images_info_path, "r", encoding="utf-8") as f_in:
        for line in f_in:
            line = line.strip()
            if not line:
                continue

            parts = line.split('\t')
            if len(parts) < 4:
                continue

            json_file_name = parts[3]
            json_file_path = os.path.join(json_dir, json_file_name)

            if not os.path.exists(json_file_path):
                missing_json_posts.append(line + '\n')
                print(f"JSON file not found: {json_file_path}")

    with open(missing_json_posts_path, "w", encoding="utf-8") as f_out:
        f_out.writelines(missing_json_posts)

# %%
# create_missing_json_posts_file(post_with_existing_images_info_path, json_dir, missing_json_posts_path)

# %%
def count_total_posts_with_missing_json(file_path=missing_json_posts_path):
    return count_posts(file_path)

# %%
total_posts_with_missing_json = count_total_posts_with_missing_json()
print(f"Total posts with missing JSON: {total_posts_with_missing_json}")
# Out:
# Total posts with missing JSON: 125

# %% [markdown]
# ##### Create new **post info txt** file with no missing image(s) and missing json

# %%
def create_no_missing_images_and_no_missing_json_post_info_file(post_with_existing_images_info_path, missing_json_posts_path, post_with_existing_images_and_json_info_path):
    with open(missing_json_posts_path, "r", encoding="utf-8") as f_missing:
        missing_posts = set(line.strip() for line in f_missing)

    with open(post_with_existing_images_info_path, "r", encoding="utf-8") as f_in, \
            open(post_with_existing_images_and_json_info_path, "w", encoding="utf-8") as f_out:

        row_number = 0
        for line in f_in:
            if line.strip() and line.strip() not in missing_posts:
                f_out.write(str(row_number) + line[line.find('\t'):])
                row_number += 1

# %%
create_no_missing_images_and_no_missing_json_post_info_file(post_with_existing_images_info_path, missing_json_posts_path, post_with_existing_images_and_json_info_path)

# %% [markdown]
# ##### Total posts **(after removing posts with missing images and missing json)**

# %%
def count_post_with_existing_images_and_json(file_path=post_with_existing_images_and_json_info_path):
    return count_posts(file_path)

# %%
total_posts_with_existing_images_and_json = count_post_with_existing_images_and_json()
print(f"Total posts with existing images and JSON: {total_posts_with_existing_images_and_json}")
# Out:
# Total posts with existing images and JSON: 1600135

# %% [markdown]
# ##### Create and total posts with missing caption

# %%
def create_missing_caption_posts_file(post_with_existing_images_and_json_info_path, json_dir, missing_caption_posts_path):
    # Read existing missing posts into a set for quick lookup
    existing_missing_posts = set()
    last_processed_line = None  # Store the last processed line

    if os.path.exists(missing_caption_posts_path):
        with open(missing_caption_posts_path, "r", encoding="utf-8") as f_missing:
            for line in f_missing:
                line = line.strip()
                existing_missing_posts.add(line)
                last_processed_line = line  # Update the last processed line

    with open(post_with_existing_images_and_json_info_path, "r", encoding="utf-8") as f_in, \
            open(missing_caption_posts_path, "a", encoding="utf-8") as f_out:

        if last_processed_line:
            # Skip lines until the last processed line is found
            for line in f_in:
                line = line.strip()
                if line == last_processed_line:
                    print(f"Resuming from: {line}")
                    break  # Start processing from the next line
            else:
                print("Last processed line not found in input file. Processing from the beginning.")
                f_in.seek(0)  # Reset file pointer to the beginning

        for line in f_in:
            line = line.strip()
            if not line:
                continue

            # Skip if the post is already in the missing_caption_posts file
            if line in existing_missing_posts:
                continue

            parts = line.split('\t')
            if len(parts) < 4:
                continue

            json_file_name = parts[3]
            json_file_path = os.path.join(json_dir, json_file_name)

            missing = False
            try:
                with open(json_file_path, 'r', encoding='utf-8') as f_json:
                    json_data = json.load(f_json)
                    if ('edge_media_to_caption' in json_data and
                            'edges' in json_data['edge_media_to_caption'] and
                            len(json_data['edge_media_to_caption']['edges']) > 0):
                        caption_text = json_data['edge_media_to_caption']['edges'][0]['node']['text']
                        if not caption_text.strip():
                            print(f"Missing caption: {json_file_path}")
                            missing = True
                    else:
                        missing = True
            except FileNotFoundError:
                print(f"JSON file not found: {json_file_path}")
                missing = True
            except json.JSONDecodeError:
                print(f"Error decoding JSON file: {json_file_path}")
                missing = True
            except KeyError:
                print(f"KeyError in JSON file: {json_file_path}")
                missing = True

            if missing:
                f_out.write(line + '\n')
                f_out.flush()

# %%
create_missing_caption_posts_file(post_with_existing_images_and_json_info_path, json_dir, missing_caption_posts_path)
# Out:
# Resuming from: 1599407	kitana_red	0	1388894981363963867.json	['1388894981363963867.jpg']

# %%
def count_total_posts_with_missing_caption(file_path=missing_caption_posts_path):
    return count_posts(file_path)

# %%
total_posts_with_missing_caption = count_total_posts_with_missing_caption()
print(f"Total posts with missing caption: {total_posts_with_missing_caption}")
# Out:
# Total posts with missing caption: 8057

# %% [markdown]
# ##### Create new **post info txt** file with no missing image(s), json, and caption

# %%
def create_no_missing_images_json_and_caption_post_info_file(post_with_existing_images_and_json_info_path, missing_caption_posts_path, post_with_existing_images_json_and_caption_info_path):
    with open(missing_caption_posts_path, "r", encoding="utf-8") as f_missing:
        missing_posts = set(line.strip() for line in f_missing)

    with open(post_with_existing_images_and_json_info_path, "r", encoding="utf-8") as f_in, \
            open(post_with_existing_images_json_and_caption_info_path, "w", encoding="utf-8") as f_out:

        row_number = 0
        for line in f_in:
            if line.strip() and line.strip() not in missing_posts:
                f_out.write(str(row_number) + line[line.find('\t'):])
                row_number += 1

# %%
create_no_missing_images_json_and_caption_post_info_file(post_with_existing_images_and_json_info_path, missing_caption_posts_path, post_with_existing_images_json_and_caption_info_path)

# %% [markdown]
# ##### Total posts **(after removing posts with missing images, json, and caption)**

# %%
def count_post_with_existing_images_json_and_caption(file_path=post_with_existing_images_json_and_caption_info_path):
    return count_posts(file_path)

# %%
total_posts_with_no_missing_data = count_post_with_existing_images_json_and_caption(post_with_existing_images_json_and_caption_info_path)
print(f"Total posts with no missing data: {total_posts_with_no_missing_data}")
# Out:
# Total posts with no missing data: 1592078

# %% [markdown]
# ##### Create and total posts with non English caption

# %%
def create_non_english_caption_posts_file(post_with_existing_images_json_and_caption_info_path, json_dir, missing_english_caption_posts_path):
    non_english_posts = set()
    last_processed_line = None

    # Read existing non-English posts into a set for quick lookup
    if os.path.exists(missing_english_caption_posts_path):
        with open(missing_english_caption_posts_path, "r", encoding="utf-8") as f_missing:
            for line in f_missing:
                line = line.strip()
                non_english_posts.add(line)
                last_processed_line = line  # Update the last processed line

    with open(post_with_existing_images_json_and_caption_info_path, "r", encoding="utf-8") as f_in, \
            open(missing_english_caption_posts_path, "a", encoding="utf-8") as f_out:

        if last_processed_line:
            # Skip lines until the last processed line is found
            for line in f_in:
                line = line.strip()
                if line == last_processed_line:
                    print(f"Resuming from: {line}")
                    break
            else:
                print("Last processed line not found in input file. Processing from the beginning.")
                f_in.seek(0)  # Reset file pointer to the beginning

        for line in f_in:
            line = line.strip()
            if not line:
                continue

            # Skip if the post is already in the non-English posts file
            if line in non_english_posts:
                continue

            parts = line.split('\t')
            if len(parts) < 4:
                continue

            json_file_name = parts[3]
            json_file_path = os.path.join(json_dir, json_file_name)

            try:
                with open(json_file_path, 'r', encoding='utf-8') as f_json:
                    json_data = json.load(f_json)
                    if ('edge_media_to_caption' in json_data and
                            'edges' in json_data['edge_media_to_caption'] and
                            len(json_data['edge_media_to_caption']['edges']) > 0):
                        caption_text = json_data['edge_media_to_caption']['edges'][0]['node']['text']
                        try:
                            if caption_text.strip() and detect(caption_text) != 'en':
                                non_english_posts.add(line)
                                f_out.write(line + '\n')
                                f_out.flush()
                                print(f"Non-English caption found in: {json_file_path}")
                        except LangDetectException:
                            print(f"Language detection failed for: {json_file_path}")
                            continue
            except Exception as e:
                print(f"Error processing {json_file_path}: {str(e)}")
                continue

# %%
create_non_english_caption_posts_file(
    post_with_existing_images_json_and_caption_info_path,
    json_dir,
    missing_english_caption_posts_path
)
# Out:
# Resuming from: 1592077	weartoeatiff	0	1986260829332127963.json	['1986260829332127963.jpg']

# %%
def count_total_non_english_posts(file_path=missing_english_caption_posts_path):
    return count_posts(file_path)

# %%
total_non_english_posts = count_total_non_english_posts()
print(f"Total posts with non-English captions: {total_non_english_posts}")
# Out:
# Total posts with non-English captions: 238369

# %% [markdown]
# ##### Create new **post info txt** file with no missing image(s), json, caption, and non-English caption

# %%
def create_no_missing_data_and_no_non_english_caption_post_info_file(post_with_existing_images_json_and_caption_info_path, missing_english_caption_posts_path, post_with_existing_images_json_caption_and_english_info_path):
    with open(missing_english_caption_posts_path, "r", encoding="utf-8") as f_missing:
        non_english_posts = set(line.strip() for line in f_missing)

    with open(post_with_existing_images_json_and_caption_info_path, "r", encoding="utf-8") as f_in, \
            open(post_with_existing_images_json_caption_and_english_info_path, "w", encoding="utf-8") as f_out:

        row_number = 0
        for line in f_in:
            if line.strip() and line.strip() not in non_english_posts:
                f_out.write(str(row_number) + line[line.find('\t'):])
                row_number += 1

# %%
create_no_missing_data_and_no_non_english_caption_post_info_file(
    post_with_existing_images_json_and_caption_info_path,
    missing_english_caption_posts_path,
    post_with_existing_images_json_caption_and_english_info_path
)

# %% [markdown]
# ##### Total posts **(after removing posts with missing image(s), json, caption, and non-English caption)**

# %%
def count_post_with_no_missing_data_and_no_non_english_caption(file_path=post_with_existing_images_json_caption_and_english_info_path):
    return count_posts(file_path)

# %%
total_posts_with_no_missing_data_and_no_non_english_caption = count_post_with_no_missing_data_and_no_non_english_caption(
    post_with_existing_images_json_caption_and_english_info_path
)
print(f"Total posts with no missing data and non-English caption: {total_posts_with_no_missing_data_and_no_non_english_caption}")
# Out:
# Total posts with no missing data and non-English caption: 1353709

# %% [markdown]
# ##### Create and total posts with no contain giveaway caption

# %%
def create_no_contain_giveaway_caption_posts_file(post_with_existing_images_json_caption_and_english_info_path, json_dir, contain_giveaway_caption_posts_path):
    contain_giveaway_posts = set()
    last_processed_line = None

    # Read existing contain giveaway posts into a set for quick lookup
    if os.path.exists(contain_giveaway_caption_posts_path):
        with open(contain_giveaway_caption_posts_path, "r", encoding="utf-8") as f_missing:
            for line in f_missing:
                line = line.strip()
                contain_giveaway_posts.add(line)
                last_processed_line = line

    with open(post_with_existing_images_json_caption_and_english_info_path, "r", encoding="utf-8") as f_in, \
            open(contain_giveaway_caption_posts_path, "a", encoding="utf-8") as f_out:

        if last_processed_line:
            # Skip lines until the last processed line is found
            for line in f_in:
                line = line.strip()
                if line == last_processed_line:
                    print(f"Resuming from: {line}")
                    break
            else:
                print("Last processed line not found in input file. Processing from the beginning.")
                f_in.seek(0)

        for line in f_in:
            line = line.strip()
            if not line:
                continue    

            # Skip if the post is already in the contain giveaway posts file
            if line in contain_giveaway_posts:
                continue

            parts = line.split('\t')
            if len(parts) < 4:
                continue

            json_file_name = parts[3]
            json_file_path = os.path.join(json_dir, json_file_name)

            try:
                with open(json_file_path, 'r', encoding='utf-8') as f_json:
                    json_data = json.load(f_json)
                    if 'edge_media_to_caption' in json_data and 'edges' in json_data['edge_media_to_caption'] and len(json_data['edge_media_to_caption']['edges']) > 0:
                        caption_text = json_data['edge_media_to_caption']['edges'][0]['node']['text']
                        if 'giveaway' in caption_text.lower():
                            contain_giveaway_posts.add(line)
                            f_out.write(line + '\n')
                            f_out.flush()
                            print(f"Contain giveaway caption found in: {json_file_path}")
            except Exception as e:
                print(f"Error processing {json_file_path}: {str(e)}")
                continue

# %%
create_no_contain_giveaway_caption_posts_file(post_with_existing_images_json_caption_and_english_info_path, json_dir, contain_giveaway_caption_posts_path)
# Out:
# Contain giveaway caption found in: ../../dataset/json\1734154912567435640.json
# Contain giveaway caption found in: ../../dataset/json\1738780832048556961.json
# Contain giveaway caption found in: ../../dataset/json\1739263002879033158.json
# Contain giveaway caption found in: ../../dataset/json\1739302443454729251.json
# Contain giveaway caption found in: ../../dataset/json\1740061834481771905.json
# Contain giveaway caption found in: ../../dataset/json\1743108500814675733.json
# Contain giveaway caption found in: ../../dataset/json\1743608020736665614.json
# Contain giveaway caption found in: ../../dataset/json\1744314854510282900.json
# Contain giveaway caption found in: ../../dataset/json\1744529133406662630.json
# Contain giveaway caption found in: ../../dataset/json\1744579686161530876.json
# Contain giveaway caption found in: ../../dataset/json\1744646158472826320.json
# Contain giveaway caption found in: ../../dataset/json\1746022435192671143.json
# Contain giveaway caption found in: ../../dataset/json\1746027924353900192.json
# Contain giveaway caption found in: ../../dataset/json\1746460955883479533.json
# Contain giveaway caption found in: ../../dataset/json\1746541437749011733.json
# Contain giveaway caption found in: ../../dataset/json\1761012810571534087.json
# Contain giveaway caption found in: ../../dataset/json\1761024221955548342.json
# Contain giveaway caption found in: ../../dataset/json\1763142165422656344.json
# Contain giveaway caption found in: ../../dataset/json\1763708638943651184.json
# Contain giveaway caption found in: ../../dataset/json\1789797792185864624.json
# Contain giveaway caption found in: ../../dataset/json\1795835096197454983.json
# Contain giveaway caption found in: ../../dataset/json\1795848596370198518.json
# Contain giveaway caption found in: ../../dataset/json\1796342163769146370.json
# Contain giveaway caption found in: ../../dataset/json\1797112930572240878.json
# Contain giveaway caption found in: ../../dataset/json\1797808021939124189.json
# Contain giveaway caption found in: ../../dataset/json\1797980662671044513.json
# Contain giveaway caption found in: ../../dataset/json\1799261241982864880.json
# Contain giveaway caption found in: ../../dataset/json\1799279934016257194.json
# Contain giveaway caption found in: ../../dataset/json\1799714560211900193.json
# Contain giveaway caption found in: ../../dataset/json\1799935127426862576.json
# Contain giveaway caption found in: ../../dataset/json\1807181349405561714.json
# Contain giveaway caption found in: ../../dataset/json\1807342016708157928.json
# Contain giveaway caption found in: ../../dataset/json\1808882100947176779.json
# Contain giveaway caption found in: ../../dataset/json\1809570218839998677.json
# Contain giveaway caption found in: ../../dataset/json\1926420799054755669.json
# Contain giveaway caption found in: ../../dataset/json\2001698485658026159.json
# Contain giveaway caption found in: ../../dataset/json\1906862112221624027.json
# Contain giveaway caption found in: ../../dataset/json\1597380648150970961.json
# Contain giveaway caption found in: ../../dataset/json\1745078823362631776.json
# Contain giveaway caption found in: ../../dataset/json\2010479914185007771.json
# Contain giveaway caption found in: ../../dataset/json\1811927165131078875.json
# Contain giveaway caption found in: ../../dataset/json\1831725889717868493.json
# Contain giveaway caption found in: ../../dataset/json\1880755517131888529.json
# Contain giveaway caption found in: ../../dataset/json\1906079743812336154.json
# Contain giveaway caption found in: ../../dataset/json\1701890418327470777.json
# Contain giveaway caption found in: ../../dataset/json\1726295224220007905.json
# Contain giveaway caption found in: ../../dataset/json\1877481402687414158.json
# Contain giveaway caption found in: ../../dataset/json\1767615106501150725.json
# Contain giveaway caption found in: ../../dataset/json\1841720593970308115.json
# Contain giveaway caption found in: ../../dataset/json\1843947371925194804.json
# Contain giveaway caption found in: ../../dataset/json\1850439367950910571.json
# Contain giveaway caption found in: ../../dataset/json\1855518656354324033.json
# Contain giveaway caption found in: ../../dataset/json\1880601927819815977.json
# Contain giveaway caption found in: ../../dataset/json\1932888226817705899.json
# Contain giveaway caption found in: ../../dataset/json\1587098320717924529.json
# Contain giveaway caption found in: ../../dataset/json\1655975976116722026.json
# Contain giveaway caption found in: ../../dataset/json\1775677289603001979.json
# Contain giveaway caption found in: ../../dataset/json\1809627324757457441.json
# Contain giveaway caption found in: ../../dataset/json\1833467642904630101.json
# Contain giveaway caption found in: ../../dataset/json\1761141321126858568.json
# Contain giveaway caption found in: ../../dataset/json\1613247730390327873.json
# Contain giveaway caption found in: ../../dataset/json\1616886495469994980.json
# Contain giveaway caption found in: ../../dataset/json\1753988107210227061.json
# Contain giveaway caption found in: ../../dataset/json\1629328166420744249.json
# Contain giveaway caption found in: ../../dataset/json\1800104690018825262.json
# Contain giveaway caption found in: ../../dataset/json\1968601135167541360.json
# Contain giveaway caption found in: ../../dataset/json\1278341517557319926.json
# Contain giveaway caption found in: ../../dataset/json\1278520347756546139.json
# Contain giveaway caption found in: ../../dataset/json\1281956101222570051.json
# Contain giveaway caption found in: ../../dataset/json\1282981527625781944.json
# Contain giveaway caption found in: ../../dataset/json\1337835064708578200.json
# Contain giveaway caption found in: ../../dataset/json\1340020960337752357.json
# Contain giveaway caption found in: ../../dataset/json\1349617904856926510.json
# Contain giveaway caption found in: ../../dataset/json\1354107879464024172.json
# Contain giveaway caption found in: ../../dataset/json\1435263381366982058.json
# Contain giveaway caption found in: ../../dataset/json\1445458573625839832.json
# Contain giveaway caption found in: ../../dataset/json\1755402929029990851.json
# Contain giveaway caption found in: ../../dataset/json\1915736636193251648.json
# Contain giveaway caption found in: ../../dataset/json\1925855103030486573.json
# Contain giveaway caption found in: ../../dataset/json\1961409271401018965.json
# Contain giveaway caption found in: ../../dataset/json\1994022920233583225.json
# Contain giveaway caption found in: ../../dataset/json\1822614637750186873.json
# Contain giveaway caption found in: ../../dataset/json\1869890294424485899.json
# Contain giveaway caption found in: ../../dataset/json\1664270707825294512.json
# Contain giveaway caption found in: ../../dataset/json\1780950627640427298.json
# Contain giveaway caption found in: ../../dataset/json\1899619557975678229.json
# Contain giveaway caption found in: ../../dataset/json\1846134211432296769.json
# Contain giveaway caption found in: ../../dataset/json\1878568024445837756.json
# Contain giveaway caption found in: ../../dataset/json\1754974026331077577.json
# Contain giveaway caption found in: ../../dataset/json\2007600208952070464.json
# Contain giveaway caption found in: ../../dataset/json\1699899299256475849.json
# Contain giveaway caption found in: ../../dataset/json\1956890618669412359.json
# Contain giveaway caption found in: ../../dataset/json\1712061759651997182.json
# Contain giveaway caption found in: ../../dataset/json\1719063004958902472.json
# Contain giveaway caption found in: ../../dataset/json\1734974639337426718.json
# Contain giveaway caption found in: ../../dataset/json\1778519953226846724.json
# Contain giveaway caption found in: ../../dataset/json\2007565622241696260.json
# Contain giveaway caption found in: ../../dataset/json\1704535713304909454.json
# Contain giveaway caption found in: ../../dataset/json\1738610644130498481.json
# Contain giveaway caption found in: ../../dataset/json\1785009491952457649.json
# Contain giveaway caption found in: ../../dataset/json\1892877950244754339.json
# Contain giveaway caption found in: ../../dataset/json\1926256120563005716.json
# Contain giveaway caption found in: ../../dataset/json\1997308972617789704.json
# Contain giveaway caption found in: ../../dataset/json\1765389517857823950.json
# Contain giveaway caption found in: ../../dataset/json\1928621689371335351.json
# Contain giveaway caption found in: ../../dataset/json\1644543090769063318.json
# Contain giveaway caption found in: ../../dataset/json\1706159983743328427.json
# Contain giveaway caption found in: ../../dataset/json\1831418445229714403.json
# Contain giveaway caption found in: ../../dataset/json\1893168283139269996.json
# Contain giveaway caption found in: ../../dataset/json\1897547142487549489.json
# Contain giveaway caption found in: ../../dataset/json\1874913865349616562.json
# Contain giveaway caption found in: ../../dataset/json\1909147800071944317.json
# Contain giveaway caption found in: ../../dataset/json\1912837217731114592.json
# Contain giveaway caption found in: ../../dataset/json\1914331070128576386.json
# Contain giveaway caption found in: ../../dataset/json\1920808224576089672.json
# Contain giveaway caption found in: ../../dataset/json\1693198330941654634.json
# Contain giveaway caption found in: ../../dataset/json\1936727192017759904.json
# Contain giveaway caption found in: ../../dataset/json\1951063790301708189.json
# Contain giveaway caption found in: ../../dataset/json\1952667746962474423.json
# Contain giveaway caption found in: ../../dataset/json\1962822151812561042.json
# Contain giveaway caption found in: ../../dataset/json\1964258684298041771.json
# Contain giveaway caption found in: ../../dataset/json\1714633633454716300.json
# Contain giveaway caption found in: ../../dataset/json\1729940229340580147.json
# Contain giveaway caption found in: ../../dataset/json\1754562749498781293.json
# Contain giveaway caption found in: ../../dataset/json\1779548581814785388.json
# Contain giveaway caption found in: ../../dataset/json\2006738131948617990.json
# Contain giveaway caption found in: ../../dataset/json\1089378834298784090.json
# Contain giveaway caption found in: ../../dataset/json\1091448880307194497.json
# Contain giveaway caption found in: ../../dataset/json\1370577671578308395.json
# Contain giveaway caption found in: ../../dataset/json\1371964589205420774.json
# Contain giveaway caption found in: ../../dataset/json\1564817036029224417.json
# Contain giveaway caption found in: ../../dataset/json\1566193022385789368.json
# Contain giveaway caption found in: ../../dataset/json\1704163014279926002.json
# Contain giveaway caption found in: ../../dataset/json\1549356590146398113.json
# Contain giveaway caption found in: ../../dataset/json\1614782691345398049.json
# Contain giveaway caption found in: ../../dataset/json\1818251043311755173.json
# Contain giveaway caption found in: ../../dataset/json\1983545575483781942.json
# Contain giveaway caption found in: ../../dataset/json\1652368492535267816.json
# Contain giveaway caption found in: ../../dataset/json\1694654885810533427.json
# Contain giveaway caption found in: ../../dataset/json\1967049520810418314.json
# Contain giveaway caption found in: ../../dataset/json\1983587481061497380.json
# Contain giveaway caption found in: ../../dataset/json\1845417664101787967.json
# Contain giveaway caption found in: ../../dataset/json\1855517466462262312.json
# Contain giveaway caption found in: ../../dataset/json\1870702728800812170.json
# Contain giveaway caption found in: ../../dataset/json\1973563667183978318.json
# Contain giveaway caption found in: ../../dataset/json\1934330280719859334.json
# Contain giveaway caption found in: ../../dataset/json\1911738808718803381.json
# Contain giveaway caption found in: ../../dataset/json\1947442709153280622.json
# Contain giveaway caption found in: ../../dataset/json\1965536077297115228.json
# Contain giveaway caption found in: ../../dataset/json\1775342067968144212.json
# Contain giveaway caption found in: ../../dataset/json\1904700501082042187.json
# Contain giveaway caption found in: ../../dataset/json\1917133174220145652.json
# Contain giveaway caption found in: ../../dataset/json\1956823029975853958.json
# Contain giveaway caption found in: ../../dataset/json\2015474352858066428.json
# Contain giveaway caption found in: ../../dataset/json\1938556611276409631.json
# Contain giveaway caption found in: ../../dataset/json\1454598516453191731.json
# Contain giveaway caption found in: ../../dataset/json\1645635834216211517.json
# Contain giveaway caption found in: ../../dataset/json\1734235634765426356.json
# Contain giveaway caption found in: ../../dataset/json\1964009683308241343.json
# Contain giveaway caption found in: ../../dataset/json\1968352226090977764.json
# Contain giveaway caption found in: ../../dataset/json\1982145197269590146.json
# Contain giveaway caption found in: ../../dataset/json\1999100691641077941.json
# Contain giveaway caption found in: ../../dataset/json\1861025140509220813.json
# Contain giveaway caption found in: ../../dataset/json\1978028795748584407.json
# Contain giveaway caption found in: ../../dataset/json\1739530214420923166.json
# Contain giveaway caption found in: ../../dataset/json\1827249584037259004.json
# Contain giveaway caption found in: ../../dataset/json\1832301455365942893.json
# Contain giveaway caption found in: ../../dataset/json\1859552329163330810.json
# Contain giveaway caption found in: ../../dataset/json\1937428223080149054.json
# Contain giveaway caption found in: ../../dataset/json\1935146364637652426.json
# Contain giveaway caption found in: ../../dataset/json\1594511700476173026.json
# Contain giveaway caption found in: ../../dataset/json\1622012169645526672.json
# Contain giveaway caption found in: ../../dataset/json\1622801428900195598.json
# Contain giveaway caption found in: ../../dataset/json\1623470065600200333.json
# Contain giveaway caption found in: ../../dataset/json\1644482332911391089.json
# Contain giveaway caption found in: ../../dataset/json\1647380343882760068.json
# Contain giveaway caption found in: ../../dataset/json\1973504177012494429.json
# Contain giveaway caption found in: ../../dataset/json\1762516348775980909.json
# Contain giveaway caption found in: ../../dataset/json\1838518140810450307.json
# Contain giveaway caption found in: ../../dataset/json\1809829848143929594.json
# Contain giveaway caption found in: ../../dataset/json\1536559019245569171.json
# Contain giveaway caption found in: ../../dataset/json\1541678871140589901.json
# Contain giveaway caption found in: ../../dataset/json\1545201350786125619.json
# Contain giveaway caption found in: ../../dataset/json\1809154434079311902.json
# Contain giveaway caption found in: ../../dataset/json\1935729231845705092.json
# Contain giveaway caption found in: ../../dataset/json\1779286371988282237.json
# Contain giveaway caption found in: ../../dataset/json\1798086690851305843.json
# Contain giveaway caption found in: ../../dataset/json\1977745484639639305.json
# Contain giveaway caption found in: ../../dataset/json\1542299075030242610.json
# Contain giveaway caption found in: ../../dataset/json\1685135853254392553.json
# Contain giveaway caption found in: ../../dataset/json\1691646092137030967.json
# Contain giveaway caption found in: ../../dataset/json\1694514028381432003.json
# Contain giveaway caption found in: ../../dataset/json\1779853733897097177.json
# Contain giveaway caption found in: ../../dataset/json\1782188315791259823.json
# Contain giveaway caption found in: ../../dataset/json\1863301984830207694.json
# Contain giveaway caption found in: ../../dataset/json\1869677276905785856.json
# Contain giveaway caption found in: ../../dataset/json\1916091946859498600.json
# Contain giveaway caption found in: ../../dataset/json\1917742825383864002.json
# Contain giveaway caption found in: ../../dataset/json\1668612353815635099.json
# Contain giveaway caption found in: ../../dataset/json\1707601110736513402.json
# Contain giveaway caption found in: ../../dataset/json\1718418566574551963.json
# Contain giveaway caption found in: ../../dataset/json\1797273688959370061.json
# Contain giveaway caption found in: ../../dataset/json\1804699349001136324.json
# Contain giveaway caption found in: ../../dataset/json\1840195350545444287.json
# Contain giveaway caption found in: ../../dataset/json\1908392570389459165.json
# Contain giveaway caption found in: ../../dataset/json\1933793413003314448.json
# Contain giveaway caption found in: ../../dataset/json\1835816348824246046.json
# Contain giveaway caption found in: ../../dataset/json\1867761118559411343.json
# Contain giveaway caption found in: ../../dataset/json\1897417185039768961.json
# Contain giveaway caption found in: ../../dataset/json\1936555448773968564.json
# Contain giveaway caption found in: ../../dataset/json\1938063788154881459.json
# Contain giveaway caption found in: ../../dataset/json\1938773484088294089.json
# Contain giveaway caption found in: ../../dataset/json\2020613605422449391.json
# Contain giveaway caption found in: ../../dataset/json\1721235849038197654.json
# Contain giveaway caption found in: ../../dataset/json\1816133473196821590.json
# Contain giveaway caption found in: ../../dataset/json\1642335069639225042.json
# Contain giveaway caption found in: ../../dataset/json\1568408895931862020.json
# Contain giveaway caption found in: ../../dataset/json\1750908628620458085.json
# Contain giveaway caption found in: ../../dataset/json\1757325440950143350.json
# Contain giveaway caption found in: ../../dataset/json\1770556711708778346.json
# Contain giveaway caption found in: ../../dataset/json\1751513685216804840.json
# Contain giveaway caption found in: ../../dataset/json\1863428137724675676.json
# Contain giveaway caption found in: ../../dataset/json\1882990204144261821.json
# Contain giveaway caption found in: ../../dataset/json\1953886018948306862.json
# Contain giveaway caption found in: ../../dataset/json\1708340987682008524.json
# Contain giveaway caption found in: ../../dataset/json\1768532671258318290.json
# Contain giveaway caption found in: ../../dataset/json\1768980268850793707.json
# Contain giveaway caption found in: ../../dataset/json\1783752622958492568.json
# Contain giveaway caption found in: ../../dataset/json\1875831415745409477.json
# Contain giveaway caption found in: ../../dataset/json\1877037654055642478.json
# Contain giveaway caption found in: ../../dataset/json\1908142803378963473.json
# Contain giveaway caption found in: ../../dataset/json\1921188853547189975.json
# Contain giveaway caption found in: ../../dataset/json\1924739418772217501.json
# Contain giveaway caption found in: ../../dataset/json\1503725715677765148.json
# Contain giveaway caption found in: ../../dataset/json\1580900465008696876.json
# Contain giveaway caption found in: ../../dataset/json\1608397747228419353.json
# Contain giveaway caption found in: ../../dataset/json\1658468562148405459.json
# Contain giveaway caption found in: ../../dataset/json\1727772674179343671.json
# Contain giveaway caption found in: ../../dataset/json\1858349664886395236.json
# Contain giveaway caption found in: ../../dataset/json\1912778536936487238.json
# Contain giveaway caption found in: ../../dataset/json\1798857888291219139.json
# Contain giveaway caption found in: ../../dataset/json\1906048078335932060.json
# Contain giveaway caption found in: ../../dataset/json\2019829151045250317.json
# Contain giveaway caption found in: ../../dataset/json\1945151386288977738.json
# Contain giveaway caption found in: ../../dataset/json\1671930014919534407.json
# Contain giveaway caption found in: ../../dataset/json\1673303198608632239.json
# Contain giveaway caption found in: ../../dataset/json\1698284344365755793.json
# Contain giveaway caption found in: ../../dataset/json\1746103997586400597.json
# Contain giveaway caption found in: ../../dataset/json\1801162724995205738.json
# Contain giveaway caption found in: ../../dataset/json\2001952802322025526.json
# Contain giveaway caption found in: ../../dataset/json\1782245605202398445.json
# Contain giveaway caption found in: ../../dataset/json\1555823969800686975.json
# Contain giveaway caption found in: ../../dataset/json\1672147700512744705.json
# Contain giveaway caption found in: ../../dataset/json\1850073294289844452.json
# Contain giveaway caption found in: ../../dataset/json\1881231505978007930.json
# Contain giveaway caption found in: ../../dataset/json\2022681887240571441.json
# Contain giveaway caption found in: ../../dataset/json\1877186408738178066.json
# Contain giveaway caption found in: ../../dataset/json\1903185450210811475.json
# Contain giveaway caption found in: ../../dataset/json\1903506558214565685.json
# Contain giveaway caption found in: ../../dataset/json\1773976034132220063.json
# Contain giveaway caption found in: ../../dataset/json\1776887159074989231.json
# Contain giveaway caption found in: ../../dataset/json\1853854553699597570.json
# Contain giveaway caption found in: ../../dataset/json\1769669947645412153.json
# Contain giveaway caption found in: ../../dataset/json\1608334284942022873.json
# Contain giveaway caption found in: ../../dataset/json\1843162828946987474.json
# Contain giveaway caption found in: ../../dataset/json\1914220701717794153.json
# Contain giveaway caption found in: ../../dataset/json\1952631242811613629.json
# Contain giveaway caption found in: ../../dataset/json\1990316739998331427.json
# Contain giveaway caption found in: ../../dataset/json\2017834619128047192.json
# Contain giveaway caption found in: ../../dataset/json\2030154549995312398.json
# Contain giveaway caption found in: ../../dataset/json\1739594929184142174.json
# Contain giveaway caption found in: ../../dataset/json\1845278040670785089.json
# Contain giveaway caption found in: ../../dataset/json\1888877347835431501.json
# Contain giveaway caption found in: ../../dataset/json\1698356360801797770.json
# Contain giveaway caption found in: ../../dataset/json\1785642405630917403.json
# Contain giveaway caption found in: ../../dataset/json\1800126007047429018.json
# Contain giveaway caption found in: ../../dataset/json\1788804808700799260.json
# Contain giveaway caption found in: ../../dataset/json\1800106643373919733.json
# Contain giveaway caption found in: ../../dataset/json\1804527577631511135.json
# Contain giveaway caption found in: ../../dataset/json\1916161195623883065.json
# Contain giveaway caption found in: ../../dataset/json\1952489431371803310.json
# Contain giveaway caption found in: ../../dataset/json\1746860681948058203.json
# Contain giveaway caption found in: ../../dataset/json\1635837759322468638.json
# Contain giveaway caption found in: ../../dataset/json\1758292338642226195.json
# Contain giveaway caption found in: ../../dataset/json\1892468969147958158.json
# Contain giveaway caption found in: ../../dataset/json\1911698495190961679.json
# Contain giveaway caption found in: ../../dataset/json\1914211477057831178.json
# Contain giveaway caption found in: ../../dataset/json\1916046993365538152.json
# Contain giveaway caption found in: ../../dataset/json\1916802548308762401.json
# Contain giveaway caption found in: ../../dataset/json\1710996488175141753.json
# Contain giveaway caption found in: ../../dataset/json\1715719502305288919.json
# Contain giveaway caption found in: ../../dataset/json\1720004741701788116.json
# Contain giveaway caption found in: ../../dataset/json\1722250292706968342.json
# Contain giveaway caption found in: ../../dataset/json\1853281574720654902.json
# Contain giveaway caption found in: ../../dataset/json\1522786765671297806.json
# Contain giveaway caption found in: ../../dataset/json\1830639326965206147.json
# Contain giveaway caption found in: ../../dataset/json\1877653006973884921.json
# Contain giveaway caption found in: ../../dataset/json\1881999560920680538.json
# Contain giveaway caption found in: ../../dataset/json\1890704383371287917.json
# Contain giveaway caption found in: ../../dataset/json\1911123176428064500.json
# Contain giveaway caption found in: ../../dataset/json\1916284741406017769.json
# Contain giveaway caption found in: ../../dataset/json\1921898493241226671.json
# Contain giveaway caption found in: ../../dataset/json\1928508649429423027.json
# Contain giveaway caption found in: ../../dataset/json\1932131177553177333.json
# Contain giveaway caption found in: ../../dataset/json\1936569787362633372.json
# Contain giveaway caption found in: ../../dataset/json\1946630617450117935.json
# Contain giveaway caption found in: ../../dataset/json\1956180215113833600.json
# Contain giveaway caption found in: ../../dataset/json\1977194501722199647.json
# Contain giveaway caption found in: ../../dataset/json\2002400789112380343.json
# Contain giveaway caption found in: ../../dataset/json\1673606501438299371.json
# Contain giveaway caption found in: ../../dataset/json\1935109983494538349.json
# Contain giveaway caption found in: ../../dataset/json\1900158311896802761.json
# Contain giveaway caption found in: ../../dataset/json\1909076196314907092.json
# Contain giveaway caption found in: ../../dataset/json\1931609417804124845.json
# Contain giveaway caption found in: ../../dataset/json\1938262407348647663.json
# Contain giveaway caption found in: ../../dataset/json\1943148217214677827.json
# Contain giveaway caption found in: ../../dataset/json\1974543026169998593.json
# Contain giveaway caption found in: ../../dataset/json\1867404290379049414.json
# Contain giveaway caption found in: ../../dataset/json\1839602587932064265.json
# Contain giveaway caption found in: ../../dataset/json\2008216866541525690.json
# Contain giveaway caption found in: ../../dataset/json\1724152738378781595.json
# Contain giveaway caption found in: ../../dataset/json\1744405774103599277.json
# Contain giveaway caption found in: ../../dataset/json\1745863608032889537.json
# Contain giveaway caption found in: ../../dataset/json\1866868525807028364.json
# Contain giveaway caption found in: ../../dataset/json\1785759966871993307.json
# Contain giveaway caption found in: ../../dataset/json\1795248339911342803.json
# Contain giveaway caption found in: ../../dataset/json\1803096568581361802.json
# Contain giveaway caption found in: ../../dataset/json\1748560114103886710.json
# Contain giveaway caption found in: ../../dataset/json\1774741868618707167.json
# Contain giveaway caption found in: ../../dataset/json\1776474176501498616.json
# Contain giveaway caption found in: ../../dataset/json\1521767315992427220.json
# Contain giveaway caption found in: ../../dataset/json\1264485518495963463.json
# Contain giveaway caption found in: ../../dataset/json\1745329489498254528.json
# Contain giveaway caption found in: ../../dataset/json\1766393294420437000.json
# Contain giveaway caption found in: ../../dataset/json\1935006711493911744.json
# Contain giveaway caption found in: ../../dataset/json\1978728390195633754.json
# Contain giveaway caption found in: ../../dataset/json\1958370887284837168.json
# Contain giveaway caption found in: ../../dataset/json\1959188862481049970.json
# Contain giveaway caption found in: ../../dataset/json\1969243015454482679.json
# Contain giveaway caption found in: ../../dataset/json\1670568248939456390.json
# Contain giveaway caption found in: ../../dataset/json\1763435629759633309.json
# Contain giveaway caption found in: ../../dataset/json\1560956385457669563.json
# Contain giveaway caption found in: ../../dataset/json\1582971842012191206.json
# Contain giveaway caption found in: ../../dataset/json\1699680639702702492.json
# Contain giveaway caption found in: ../../dataset/json\1954083973354674153.json
# Contain giveaway caption found in: ../../dataset/json\1695065747658053784.json
# Contain giveaway caption found in: ../../dataset/json\1713502748761532420.json
# Contain giveaway caption found in: ../../dataset/json\1814124801331998012.json
# Contain giveaway caption found in: ../../dataset/json\1815266466453244168.json
# Contain giveaway caption found in: ../../dataset/json\1815453535278628952.json
# Contain giveaway caption found in: ../../dataset/json\1713192386421993053.json
# Contain giveaway caption found in: ../../dataset/json\1761734568770410453.json
# Contain giveaway caption found in: ../../dataset/json\1933689445501679253.json
# Contain giveaway caption found in: ../../dataset/json\1719901845332116725.json
# Contain giveaway caption found in: ../../dataset/json\1739485370053187854.json
# Contain giveaway caption found in: ../../dataset/json\1747459382504701936.json
# Contain giveaway caption found in: ../../dataset/json\1912064213501899670.json
# Contain giveaway caption found in: ../../dataset/json\1426976231065108087.json
# Contain giveaway caption found in: ../../dataset/json\1696660174734195392.json
# Contain giveaway caption found in: ../../dataset/json\1888614794145007244.json
# Contain giveaway caption found in: ../../dataset/json\1485981859941921625.json
# Contain giveaway caption found in: ../../dataset/json\1597952193038441762.json
# Contain giveaway caption found in: ../../dataset/json\1761370762012294809.json
# Contain giveaway caption found in: ../../dataset/json\1866954041624659741.json
# Contain giveaway caption found in: ../../dataset/json\1890146284095145647.json
# Contain giveaway caption found in: ../../dataset/json\1742351505941502735.json
# Contain giveaway caption found in: ../../dataset/json\1919003948578486425.json
# Contain giveaway caption found in: ../../dataset/json\2020520770351227942.json
# Contain giveaway caption found in: ../../dataset/json\1430673174227812010.json
# Contain giveaway caption found in: ../../dataset/json\1819142349470474717.json
# Contain giveaway caption found in: ../../dataset/json\1644382313574675767.json
# Contain giveaway caption found in: ../../dataset/json\1650454289951135668.json
# Contain giveaway caption found in: ../../dataset/json\1674086654607784602.json
# Contain giveaway caption found in: ../../dataset/json\1936693504659790153.json
# Contain giveaway caption found in: ../../dataset/json\1957078657311662762.json
# Contain giveaway caption found in: ../../dataset/json\2013977494168180777.json
# Contain giveaway caption found in: ../../dataset/json\1390703439788397482.json
# Contain giveaway caption found in: ../../dataset/json\1787990125796429638.json
# Contain giveaway caption found in: ../../dataset/json\1813356413049658048.json
# Contain giveaway caption found in: ../../dataset/json\1822332959517853764.json
# Contain giveaway caption found in: ../../dataset/json\1922829557578532807.json
# Contain giveaway caption found in: ../../dataset/json\1930497144244154935.json
# Contain giveaway caption found in: ../../dataset/json\1962314166720330193.json
# Contain giveaway caption found in: ../../dataset/json\2020460472894415952.json
# Contain giveaway caption found in: ../../dataset/json\1684340074349981926.json
# Contain giveaway caption found in: ../../dataset/json\1962616945002798137.json
# Contain giveaway caption found in: ../../dataset/json\1974243197043686140.json
# Contain giveaway caption found in: ../../dataset/json\1974917465997917726.json
# Contain giveaway caption found in: ../../dataset/json\1975641244709497429.json
# Contain giveaway caption found in: ../../dataset/json\1767495850306841966.json
# Contain giveaway caption found in: ../../dataset/json\1516932114892040187.json
# Contain giveaway caption found in: ../../dataset/json\1672746510809097342.json
# Contain giveaway caption found in: ../../dataset/json\1851035600502076520.json
# Contain giveaway caption found in: ../../dataset/json\1863341892381717834.json
# Contain giveaway caption found in: ../../dataset/json\1741753566896065842.json
# Contain giveaway caption found in: ../../dataset/json\1877261684626602061.json
# Contain giveaway caption found in: ../../dataset/json\1876379804761523567.json
# Contain giveaway caption found in: ../../dataset/json\1885033901701868911.json
# Contain giveaway caption found in: ../../dataset/json\1889543773533289398.json
# Contain giveaway caption found in: ../../dataset/json\1924186376694365407.json
# Contain giveaway caption found in: ../../dataset/json\1937484062855944401.json
# Contain giveaway caption found in: ../../dataset/json\1880186412902652472.json
# Contain giveaway caption found in: ../../dataset/json\1885795058248358031.json
# Contain giveaway caption found in: ../../dataset/json\1909662269283113251.json
# Contain giveaway caption found in: ../../dataset/json\1963954950335086683.json
# Contain giveaway caption found in: ../../dataset/json\1978605066139732169.json
# Contain giveaway caption found in: ../../dataset/json\1720549711655393439.json
# Contain giveaway caption found in: ../../dataset/json\1724737535455686815.json
# Contain giveaway caption found in: ../../dataset/json\1758863421049932904.json
# Contain giveaway caption found in: ../../dataset/json\1872676207906919817.json
# Contain giveaway caption found in: ../../dataset/json\1969719519316546037.json
# Contain giveaway caption found in: ../../dataset/json\1695845508658922900.json
# Contain giveaway caption found in: ../../dataset/json\1700242644519368225.json
# Contain giveaway caption found in: ../../dataset/json\1702433758718583112.json
# Contain giveaway caption found in: ../../dataset/json\2007814700953071145.json
# Contain giveaway caption found in: ../../dataset/json\1765549871133015729.json
# Contain giveaway caption found in: ../../dataset/json\1550123096441494555.json
# Contain giveaway caption found in: ../../dataset/json\1694645713721641719.json
# Contain giveaway caption found in: ../../dataset/json\1840292053378867916.json
# Contain giveaway caption found in: ../../dataset/json\1847471226304178694.json
# Contain giveaway caption found in: ../../dataset/json\1736098309360496937.json
# Contain giveaway caption found in: ../../dataset/json\1832891753356882213.json
# Contain giveaway caption found in: ../../dataset/json\1869812801804326955.json
# Contain giveaway caption found in: ../../dataset/json\1880468326694723648.json
# Contain giveaway caption found in: ../../dataset/json\1978642758637955200.json
# Contain giveaway caption found in: ../../dataset/json\1957710178069535279.json
# Contain giveaway caption found in: ../../dataset/json\2009174533617112784.json
# Contain giveaway caption found in: ../../dataset/json\1827259656943546291.json
# Contain giveaway caption found in: ../../dataset/json\1823942378144081663.json
# Contain giveaway caption found in: ../../dataset/json\1143658307631221115.json
# Contain giveaway caption found in: ../../dataset/json\1187869362204739999.json
# Contain giveaway caption found in: ../../dataset/json\1645131883255082103.json
# Contain giveaway caption found in: ../../dataset/json\1818253033316042766.json
# Contain giveaway caption found in: ../../dataset/json\1871309070581978906.json
# Contain giveaway caption found in: ../../dataset/json\1765354066415734987.json
# Contain giveaway caption found in: ../../dataset/json\1784943032643155413.json
# Contain giveaway caption found in: ../../dataset/json\1863426532018543740.json
# Contain giveaway caption found in: ../../dataset/json\1886627070194154122.json
# Contain giveaway caption found in: ../../dataset/json\1887103693745859863.json
# Contain giveaway caption found in: ../../dataset/json\1936499391650928931.json
# Contain giveaway caption found in: ../../dataset/json\1949593357682286772.json
# Contain giveaway caption found in: ../../dataset/json\1989396976015046685.json
# Contain giveaway caption found in: ../../dataset/json\1992997828520984647.json
# Contain giveaway caption found in: ../../dataset/json\1921314354043293957.json
# Contain giveaway caption found in: ../../dataset/json\1999482559492199751.json
# Contain giveaway caption found in: ../../dataset/json\1739420144138050512.json
# Contain giveaway caption found in: ../../dataset/json\1746920655216999528.json
# Contain giveaway caption found in: ../../dataset/json\1795961122944218523.json
# Contain giveaway caption found in: ../../dataset/json\1935819284938601307.json
# Contain giveaway caption found in: ../../dataset/json\1892881999811864522.json
# Contain giveaway caption found in: ../../dataset/json\1856150682961568152.json
# Contain giveaway caption found in: ../../dataset/json\1812604033463280249.json
# Contain giveaway caption found in: ../../dataset/json\1910312989561295624.json
# Contain giveaway caption found in: ../../dataset/json\1922042874272950844.json
# Contain giveaway caption found in: ../../dataset/json\1873124115238388991.json
# Contain giveaway caption found in: ../../dataset/json\1489288236614275688.json
# Contain giveaway caption found in: ../../dataset/json\1623926893186064812.json
# Contain giveaway caption found in: ../../dataset/json\1676774473049421916.json
# Contain giveaway caption found in: ../../dataset/json\1865510192169094656.json
# Contain giveaway caption found in: ../../dataset/json\1869843788124158279.json
# Contain giveaway caption found in: ../../dataset/json\1833493159154768879.json
# Contain giveaway caption found in: ../../dataset/json\1966470458614622264.json
# Contain giveaway caption found in: ../../dataset/json\1344526183949446351.json
# Contain giveaway caption found in: ../../dataset/json\1457719425112524498.json
# Contain giveaway caption found in: ../../dataset/json\1598255968516816169.json
# Contain giveaway caption found in: ../../dataset/json\1694451253844098472.json
# Contain giveaway caption found in: ../../dataset/json\1888529497579771990.json
# Contain giveaway caption found in: ../../dataset/json\1603873950718113977.json
# Contain giveaway caption found in: ../../dataset/json\1903087429402098405.json
# Contain giveaway caption found in: ../../dataset/json\1967132965239367005.json
# Contain giveaway caption found in: ../../dataset/json\1997392613389202080.json
# Contain giveaway caption found in: ../../dataset/json\1992540644148671575.json
# Contain giveaway caption found in: ../../dataset/json\1703264530626291781.json
# Contain giveaway caption found in: ../../dataset/json\1703746335091638265.json
# Contain giveaway caption found in: ../../dataset/json\1705653517810877955.json
# Contain giveaway caption found in: ../../dataset/json\1584099852970411234.json
# Contain giveaway caption found in: ../../dataset/json\1650239638046783798.json
# Contain giveaway caption found in: ../../dataset/json\1831297965006734862.json
# Contain giveaway caption found in: ../../dataset/json\1933514375438495761.json
# Contain giveaway caption found in: ../../dataset/json\1931895362265912730.json
# Contain giveaway caption found in: ../../dataset/json\1716345362085816622.json
# Contain giveaway caption found in: ../../dataset/json\1719256858113547781.json
# Contain giveaway caption found in: ../../dataset/json\1909054470610011619.json
# Contain giveaway caption found in: ../../dataset/json\1997569101221283350.json
# Contain giveaway caption found in: ../../dataset/json\1999602654142344959.json
# Contain giveaway caption found in: ../../dataset/json\1938379318061274960.json
# Contain giveaway caption found in: ../../dataset/json\1844302314740228179.json
# Contain giveaway caption found in: ../../dataset/json\1613198697675352740.json
# Contain giveaway caption found in: ../../dataset/json\1665538219095936291.json
# Contain giveaway caption found in: ../../dataset/json\1832803835485359314.json
# Contain giveaway caption found in: ../../dataset/json\1799919624096455207.json
# Contain giveaway caption found in: ../../dataset/json\1734557812728927258.json
# Contain giveaway caption found in: ../../dataset/json\1744597514973111166.json
# Contain giveaway caption found in: ../../dataset/json\1924563723889087191.json
# Contain giveaway caption found in: ../../dataset/json\1999738901400626809.json
# Contain giveaway caption found in: ../../dataset/json\1761929328289131867.json
# Contain giveaway caption found in: ../../dataset/json\1777936698070003280.json
# Contain giveaway caption found in: ../../dataset/json\1801774396647791047.json
# Contain giveaway caption found in: ../../dataset/json\1801889432280115824.json
# Contain giveaway caption found in: ../../dataset/json\1831279590188049334.json
# Contain giveaway caption found in: ../../dataset/json\1854042164070603293.json
# Contain giveaway caption found in: ../../dataset/json\1878770405327933093.json
# Contain giveaway caption found in: ../../dataset/json\1902064232029482489.json
# Contain giveaway caption found in: ../../dataset/json\1932404210058819022.json
# Contain giveaway caption found in: ../../dataset/json\1939506620208213865.json
# Contain giveaway caption found in: ../../dataset/json\1964992333556972579.json
# Contain giveaway caption found in: ../../dataset/json\1969197063019604668.json
# Contain giveaway caption found in: ../../dataset/json\1751081085296444338.json
# Contain giveaway caption found in: ../../dataset/json\1758460747547092564.json
# Contain giveaway caption found in: ../../dataset/json\1798034567605709524.json
# Contain giveaway caption found in: ../../dataset/json\1848195793299840667.json
# Contain giveaway caption found in: ../../dataset/json\1908189423771389099.json
# Contain giveaway caption found in: ../../dataset/json\1916173780348001706.json
# Contain giveaway caption found in: ../../dataset/json\1988655638989682825.json
# Contain giveaway caption found in: ../../dataset/json\2035099909757873127.json
# Contain giveaway caption found in: ../../dataset/json\1753242440826174716.json
# Contain giveaway caption found in: ../../dataset/json\1782154403566967930.json
# Contain giveaway caption found in: ../../dataset/json\1890975903443742446.json
# Contain giveaway caption found in: ../../dataset/json\1493216983163821927.json
# Contain giveaway caption found in: ../../dataset/json\1709868295040909489.json
# Contain giveaway caption found in: ../../dataset/json\1929531334244234702.json
# Contain giveaway caption found in: ../../dataset/json\1929914473303154276.json
# Contain giveaway caption found in: ../../dataset/json\1837093581207294147.json
# Contain giveaway caption found in: ../../dataset/json\1922624178876435072.json
# Contain giveaway caption found in: ../../dataset/json\1852322711536169778.json
# Contain giveaway caption found in: ../../dataset/json\1933644318497980573.json
# Contain giveaway caption found in: ../../dataset/json\2017561799507133588.json
# Contain giveaway caption found in: ../../dataset/json\1795627794953580380.json
# Contain giveaway caption found in: ../../dataset/json\1844914624093711128.json
# Contain giveaway caption found in: ../../dataset/json\1850697560764018758.json
# Contain giveaway caption found in: ../../dataset/json\1915215962139827109.json
# Contain giveaway caption found in: ../../dataset/json\2001404107777423480.json
# Contain giveaway caption found in: ../../dataset/json\1968721412471712117.json
# Contain giveaway caption found in: ../../dataset/json\2034788090174538077.json
# Contain giveaway caption found in: ../../dataset/json\1637364330310503523.json
# Contain giveaway caption found in: ../../dataset/json\1644625290201114675.json
# Contain giveaway caption found in: ../../dataset/json\1749533194300709460.json
# Contain giveaway caption found in: ../../dataset/json\1755211101706294794.json
# Contain giveaway caption found in: ../../dataset/json\1759093976352541778.json
# Contain giveaway caption found in: ../../dataset/json\1454818612406072866.json
# Contain giveaway caption found in: ../../dataset/json\1493922499163256579.json
# Contain giveaway caption found in: ../../dataset/json\1763866939460183405.json
# Contain giveaway caption found in: ../../dataset/json\1804764944686003227.json
# Contain giveaway caption found in: ../../dataset/json\1806334626450840184.json
# Contain giveaway caption found in: ../../dataset/json\1584359349382618113.json
# Contain giveaway caption found in: ../../dataset/json\1749401524512410957.json
# Contain giveaway caption found in: ../../dataset/json\1750215951755022359.json
# Contain giveaway caption found in: ../../dataset/json\1849509575477670630.json
# Contain giveaway caption found in: ../../dataset/json\1901041917011768207.json
# Contain giveaway caption found in: ../../dataset/json\1905315119846373664.json
# Contain giveaway caption found in: ../../dataset/json\1927139839109404540.json
# Contain giveaway caption found in: ../../dataset/json\1927815729069927396.json
# Contain giveaway caption found in: ../../dataset/json\1930716786439730121.json
# Contain giveaway caption found in: ../../dataset/json\1936481110684651921.json
# Contain giveaway caption found in: ../../dataset/json\1941589097883404985.json
# Contain giveaway caption found in: ../../dataset/json\1987345382503124151.json
# Contain giveaway caption found in: ../../dataset/json\1826322229086855383.json
# Contain giveaway caption found in: ../../dataset/json\1848798061105472267.json
# Contain giveaway caption found in: ../../dataset/json\1532206308329367065.json
# Contain giveaway caption found in: ../../dataset/json\1544635029007049683.json
# Contain giveaway caption found in: ../../dataset/json\1661945609715042023.json
# Contain giveaway caption found in: ../../dataset/json\1663302381822316207.json
# Contain giveaway caption found in: ../../dataset/json\1455168964808550553.json
# Contain giveaway caption found in: ../../dataset/json\1483522811003941044.json
# Contain giveaway caption found in: ../../dataset/json\1508094837639343348.json
# Contain giveaway caption found in: ../../dataset/json\1514625290919684119.json
# Contain giveaway caption found in: ../../dataset/json\1517524007003839204.json
# Contain giveaway caption found in: ../../dataset/json\1561732883775887041.json
# Contain giveaway caption found in: ../../dataset/json\1571854444465854869.json
# Contain giveaway caption found in: ../../dataset/json\1629860926033460974.json
# Contain giveaway caption found in: ../../dataset/json\1660519314089982667.json
# Contain giveaway caption found in: ../../dataset/json\1661240240423122826.json
# Contain giveaway caption found in: ../../dataset/json\1662657818630723299.json
# Contain giveaway caption found in: ../../dataset/json\1653083535786117868.json
# Contain giveaway caption found in: ../../dataset/json\1916139771344923541.json
# Contain giveaway caption found in: ../../dataset/json\1526182052931418199.json
# Contain giveaway caption found in: ../../dataset/json\1586324378157361281.json
# Contain giveaway caption found in: ../../dataset/json\1764695665303935328.json
# Contain giveaway caption found in: ../../dataset/json\1581593147972304687.json
# Contain giveaway caption found in: ../../dataset/json\1582765358523475977.json
# Contain giveaway caption found in: ../../dataset/json\1583521361913285443.json
# Contain giveaway caption found in: ../../dataset/json\1628057397469036552.json
# Contain giveaway caption found in: ../../dataset/json\1671430291448117267.json
# Contain giveaway caption found in: ../../dataset/json\1658701044174992901.json
# Contain giveaway caption found in: ../../dataset/json\1663810691026254049.json
# Contain giveaway caption found in: ../../dataset/json\1668835896119406939.json
# Contain giveaway caption found in: ../../dataset/json\1822462261537764531.json
# Contain giveaway caption found in: ../../dataset/json\1897044017763651783.json
# Contain giveaway caption found in: ../../dataset/json\1901459287211208070.json
# Contain giveaway caption found in: ../../dataset/json\1906487107872200802.json
# Contain giveaway caption found in: ../../dataset/json\1907967816990436617.json
# Contain giveaway caption found in: ../../dataset/json\1936263810035212428.json
# Contain giveaway caption found in: ../../dataset/json\1938464649332018235.json
# Contain giveaway caption found in: ../../dataset/json\1757646701400093492.json
# Contain giveaway caption found in: ../../dataset/json\1819754212995030101.json
# Contain giveaway caption found in: ../../dataset/json\1927938260157613515.json
# Contain giveaway caption found in: ../../dataset/json\1945957998704171668.json
# Contain giveaway caption found in: ../../dataset/json\1988938738177621316.json
# Contain giveaway caption found in: ../../dataset/json\1654663880184831729.json
# Contain giveaway caption found in: ../../dataset/json\1724567773449123018.json
# Contain giveaway caption found in: ../../dataset/json\1779363797874783468.json
# Contain giveaway caption found in: ../../dataset/json\1592230182356726774.json
# Contain giveaway caption found in: ../../dataset/json\1883711614970274097.json
# Contain giveaway caption found in: ../../dataset/json\1923558285250621795.json
# Contain giveaway caption found in: ../../dataset/json\1670363080482040183.json
# Contain giveaway caption found in: ../../dataset/json\1736264278606328082.json
# Contain giveaway caption found in: ../../dataset/json\1781963093687206579.json
# ...
# Contain giveaway caption found in: ../../dataset/json\1937200993198380066.json
# Contain giveaway caption found in: ../../dataset/json\1657415939678087618.json
# Contain giveaway caption found in: ../../dataset/json\1659568221123509077.json
# Contain giveaway caption found in: ../../dataset/json\1662492329977049931.json
# Contain giveaway caption found in: ../../dataset/json\1663220981924406299.json
# Contain giveaway caption found in: ../../dataset/json\1673259787864076776.json
# Contain giveaway caption found in: ../../dataset/json\1705186302728636301.json
# Contain giveaway caption found in: ../../dataset/json\1769874322639474682.json
# Contain giveaway caption found in: ../../dataset/json\1805374589455335275.json
# Contain giveaway caption found in: ../../dataset/json\1822699082905501970.json
# Contain giveaway caption found in: ../../dataset/json\1824860073235629358.json
# Contain giveaway caption found in: ../../dataset/json\1830752911265679660.json
# Contain giveaway caption found in: ../../dataset/json\1780792719972954981.json
# Contain giveaway caption found in: ../../dataset/json\1790333462555600300.json
# Contain giveaway caption found in: ../../dataset/json\1792575437463767341.json
# Contain giveaway caption found in: ../../dataset/json\1797593990063629044.json
# Contain giveaway caption found in: ../../dataset/json\1811373831057354231.json
# Contain giveaway caption found in: ../../dataset/json\1897280380903263593.json
# Contain giveaway caption found in: ../../dataset/json\1900921181898796637.json
# Contain giveaway caption found in: ../../dataset/json\1902425812565804832.json
# Contain giveaway caption found in: ../../dataset/json\1916391183337133570.json
# Contain giveaway caption found in: ../../dataset/json\1830116466226433076.json
# Contain giveaway caption found in: ../../dataset/json\1902602161204761334.json
# Contain giveaway caption found in: ../../dataset/json\1806762331364236784.json
# Contain giveaway caption found in: ../../dataset/json\1812566190724578373.json
# Contain giveaway caption found in: ../../dataset/json\1819528626497270818.json
# Contain giveaway caption found in: ../../dataset/json\1826187520271269917.json
# Contain giveaway caption found in: ../../dataset/json\1913698543743480876.json
# Contain giveaway caption found in: ../../dataset/json\1659874146156640734.json
# Contain giveaway caption found in: ../../dataset/json\1704117905396154967.json
# Contain giveaway caption found in: ../../dataset/json\1739647256984090886.json
# Contain giveaway caption found in: ../../dataset/json\1765724331830445137.json
# Contain giveaway caption found in: ../../dataset/json\1790823744840115457.json
# Contain giveaway caption found in: ../../dataset/json\1804613275154224597.json
# Contain giveaway caption found in: ../../dataset/json\1831989669286697033.json
# Contain giveaway caption found in: ../../dataset/json\1850341262902121041.json
# Contain giveaway caption found in: ../../dataset/json\1878150370602268217.json
# Contain giveaway caption found in: ../../dataset/json\1890092695981280712.json
# Contain giveaway caption found in: ../../dataset/json\1999506799958613484.json
# Contain giveaway caption found in: ../../dataset/json\1578039733874254045.json
# Contain giveaway caption found in: ../../dataset/json\1862825819647748792.json
# Contain giveaway caption found in: ../../dataset/json\1867171615323055467.json
# Contain giveaway caption found in: ../../dataset/json\1967756232697950475.json
# Contain giveaway caption found in: ../../dataset/json\2007361677875854253.json
# Contain giveaway caption found in: ../../dataset/json\1939985037269374834.json
# Contain giveaway caption found in: ../../dataset/json\1901864019880754290.json
# Contain giveaway caption found in: ../../dataset/json\1908306276988003220.json
# Contain giveaway caption found in: ../../dataset/json\1910423547244027803.json
# Contain giveaway caption found in: ../../dataset/json\1769731361978372506.json
# Contain giveaway caption found in: ../../dataset/json\1533498343761624661.json
# Contain giveaway caption found in: ../../dataset/json\1635090242712025151.json
# Contain giveaway caption found in: ../../dataset/json\1766208079769086027.json
# Contain giveaway caption found in: ../../dataset/json\1961912673302130025.json
# Contain giveaway caption found in: ../../dataset/json\1932918872275278046.json
# Contain giveaway caption found in: ../../dataset/json\1937414349162208331.json
# Contain giveaway caption found in: ../../dataset/json\1657362039993355369.json
# Contain giveaway caption found in: ../../dataset/json\1660358765662641467.json
# Contain giveaway caption found in: ../../dataset/json\1663890039488537829.json
# Contain giveaway caption found in: ../../dataset/json\1668234490570758599.json
# Contain giveaway caption found in: ../../dataset/json\1716065310479761856.json
# Contain giveaway caption found in: ../../dataset/json\1736332325945860044.json
# Contain giveaway caption found in: ../../dataset/json\1792130769844219540.json
# Contain giveaway caption found in: ../../dataset/json\1924886806916847251.json
# Contain giveaway caption found in: ../../dataset/json\1926979651224162520.json
# Contain giveaway caption found in: ../../dataset/json\1928425794973886799.json
# Contain giveaway caption found in: ../../dataset/json\1931330309440131288.json
# Contain giveaway caption found in: ../../dataset/json\1934244576233377431.json
# Contain giveaway caption found in: ../../dataset/json\1935692819500801761.json
# Contain giveaway caption found in: ../../dataset/json\1941471646181048780.json
# Contain giveaway caption found in: ../../dataset/json\1979162058865617305.json
# Contain giveaway caption found in: ../../dataset/json\2000159680656927380.json
# Contain giveaway caption found in: ../../dataset/json\2001896499438211059.json
# Contain giveaway caption found in: ../../dataset/json\2007389377522484628.json
# Contain giveaway caption found in: ../../dataset/json\1636475451025350449.json
# Contain giveaway caption found in: ../../dataset/json\1643880112124571935.json
# Contain giveaway caption found in: ../../dataset/json\1678540107495304198.json
# Contain giveaway caption found in: ../../dataset/json\1786518733957473697.json
# Contain giveaway caption found in: ../../dataset/json\1796154558081101160.json
# Contain giveaway caption found in: ../../dataset/json\1944663808758242979.json
# Contain giveaway caption found in: ../../dataset/json\1720044087627574064.json
# Contain giveaway caption found in: ../../dataset/json\1793820903798059188.json
# Contain giveaway caption found in: ../../dataset/json\1403902762509392693.json
# Contain giveaway caption found in: ../../dataset/json\1944720448891557441.json
# Contain giveaway caption found in: ../../dataset/json\1959963332913882173.json
# Contain giveaway caption found in: ../../dataset/json\1960699110262407777.json
# Contain giveaway caption found in: ../../dataset/json\1961083072486928479.json
# Contain giveaway caption found in: ../../dataset/json\1966211573565226175.json
# Contain giveaway caption found in: ../../dataset/json\1979900116338679262.json
# Contain giveaway caption found in: ../../dataset/json\1980274795368838491.json
# Contain giveaway caption found in: ../../dataset/json\1980941532158256929.json
# Contain giveaway caption found in: ../../dataset/json\1982450698983195312.json
# Contain giveaway caption found in: ../../dataset/json\1990800397498837692.json
# Contain giveaway caption found in: ../../dataset/json\1999773886184239168.json
# Contain giveaway caption found in: ../../dataset/json\2000112868264837052.json
# Contain giveaway caption found in: ../../dataset/json\2000921636166710624.json
# Contain giveaway caption found in: ../../dataset/json\2004849534905086221.json
# Contain giveaway caption found in: ../../dataset/json\2009922516333558843.json
# Contain giveaway caption found in: ../../dataset/json\1567079793369980267.json
# Contain giveaway caption found in: ../../dataset/json\1515747376400663179.json
# Contain giveaway caption found in: ../../dataset/json\1921840841762463865.json
# Contain giveaway caption found in: ../../dataset/json\1782540176146660490.json
# Contain giveaway caption found in: ../../dataset/json\1937223468483773488.json
# Contain giveaway caption found in: ../../dataset/json\2007538446020881703.json
# Contain giveaway caption found in: ../../dataset/json\1748218878516624147.json
# Contain giveaway caption found in: ../../dataset/json\1749422298162380110.json
# Contain giveaway caption found in: ../../dataset/json\1791744186522106187.json
# Contain giveaway caption found in: ../../dataset/json\1800979567255926472.json
# Contain giveaway caption found in: ../../dataset/json\1951817700305077970.json
# Contain giveaway caption found in: ../../dataset/json\1811164377942735346.json
# Contain giveaway caption found in: ../../dataset/json\2008118493660058154.json
# Contain giveaway caption found in: ../../dataset/json\1870232232741227060.json
# Contain giveaway caption found in: ../../dataset/json\1835812768903004100.json
# Contain giveaway caption found in: ../../dataset/json\1835992009128943058.json
# Contain giveaway caption found in: ../../dataset/json\1842365229083968268.json
# Contain giveaway caption found in: ../../dataset/json\1866541890901827224.json
# Contain giveaway caption found in: ../../dataset/json\1877092022897592179.json
# Contain giveaway caption found in: ../../dataset/json\1881552276112702715.json
# Contain giveaway caption found in: ../../dataset/json\1925554394419749435.json
# Contain giveaway caption found in: ../../dataset/json\1928033728833289379.json
# Contain giveaway caption found in: ../../dataset/json\2017588040634216888.json
# Contain giveaway caption found in: ../../dataset/json\1817357057756291229.json
# Contain giveaway caption found in: ../../dataset/json\1896244469747742743.json
# Contain giveaway caption found in: ../../dataset/json\1837792180020105557.json
# Contain giveaway caption found in: ../../dataset/json\1888520650641956525.json
# Contain giveaway caption found in: ../../dataset/json\1662523929031379952.json
# Contain giveaway caption found in: ../../dataset/json\1716159806370309180.json
# Contain giveaway caption found in: ../../dataset/json\1934284642866026529.json
# Contain giveaway caption found in: ../../dataset/json\1865689566369214012.json
# Contain giveaway caption found in: ../../dataset/json\1950972273693135459.json
# Contain giveaway caption found in: ../../dataset/json\1973466746356359827.json
# Contain giveaway caption found in: ../../dataset/json\1978702372290768002.json
# Contain giveaway caption found in: ../../dataset/json\1993743141921730274.json
# Contain giveaway caption found in: ../../dataset/json\2012623513103217434.json
# Contain giveaway caption found in: ../../dataset/json\1527099976739381548.json
# Contain giveaway caption found in: ../../dataset/json\1695491789086431939.json
# Contain giveaway caption found in: ../../dataset/json\1807077905218647244.json
# Contain giveaway caption found in: ../../dataset/json\1886812999914947482.json
# Contain giveaway caption found in: ../../dataset/json\1984872781950498654.json
# Contain giveaway caption found in: ../../dataset/json\2006073393081959608.json
# Contain giveaway caption found in: ../../dataset/json\1949313778480120426.json
# Contain giveaway caption found in: ../../dataset/json\1951739402943479895.json
# Contain giveaway caption found in: ../../dataset/json\1957054044154641085.json
# Contain giveaway caption found in: ../../dataset/json\1958412020950057562.json
# Contain giveaway caption found in: ../../dataset/json\1962173538485389419.json
# Contain giveaway caption found in: ../../dataset/json\1963899886706758572.json
# Contain giveaway caption found in: ../../dataset/json\1807671656347315568.json
# Contain giveaway caption found in: ../../dataset/json\1975132175632340584.json
# Contain giveaway caption found in: ../../dataset/json\1479389031682266361.json
# Contain giveaway caption found in: ../../dataset/json\1480841830257339616.json
# Contain giveaway caption found in: ../../dataset/json\1491708263090388417.json
# Contain giveaway caption found in: ../../dataset/json\1644667589362041701.json
# Contain giveaway caption found in: ../../dataset/json\1770024568096606980.json
# Contain giveaway caption found in: ../../dataset/json\1771268198206056822.json
# Contain giveaway caption found in: ../../dataset/json\1796114030207634487.json
# Contain giveaway caption found in: ../../dataset/json\1590115603543348196.json
# Contain giveaway caption found in: ../../dataset/json\1765428908125387229.json
# Contain giveaway caption found in: ../../dataset/json\1841791594265983477.json
# Contain giveaway caption found in: ../../dataset/json\1866151049807667024.json
# Contain giveaway caption found in: ../../dataset/json\1896133174032033994.json
# Contain giveaway caption found in: ../../dataset/json\1848362681577276059.json
# Contain giveaway caption found in: ../../dataset/json\1849047360953442850.json
# Contain giveaway caption found in: ../../dataset/json\1850336989920939395.json
# Contain giveaway caption found in: ../../dataset/json\1744477748878992054.json
# Contain giveaway caption found in: ../../dataset/json\1811748226342562925.json
# Contain giveaway caption found in: ../../dataset/json\1814108547942112410.json
# Contain giveaway caption found in: ../../dataset/json\1834925580869623079.json
# Contain giveaway caption found in: ../../dataset/json\1971333144854450538.json
# Contain giveaway caption found in: ../../dataset/json\1766921665524848039.json
# Contain giveaway caption found in: ../../dataset/json\1768494150259249872.json
# Contain giveaway caption found in: ../../dataset/json\1787242744629934159.json
# Contain giveaway caption found in: ../../dataset/json\1788764286362666790.json
# Contain giveaway caption found in: ../../dataset/json\1906619906682936989.json
# Contain giveaway caption found in: ../../dataset/json\1907445719758127848.json
# Contain giveaway caption found in: ../../dataset/json\1796496120497351703.json
# Contain giveaway caption found in: ../../dataset/json\1974063590000393402.json
# Contain giveaway caption found in: ../../dataset/json\2017726067392936729.json
# Contain giveaway caption found in: ../../dataset/json\1724410306653227042.json
# Contain giveaway caption found in: ../../dataset/json\1756874668008500851.json
# Contain giveaway caption found in: ../../dataset/json\1867652736234115504.json
# Contain giveaway caption found in: ../../dataset/json\1814607953375606869.json
# Contain giveaway caption found in: ../../dataset/json\1428439630583334629.json
# Contain giveaway caption found in: ../../dataset/json\1440780146691908195.json
# Contain giveaway caption found in: ../../dataset/json\1453797425261017170.json
# Contain giveaway caption found in: ../../dataset/json\1464650392499311406.json
# Contain giveaway caption found in: ../../dataset/json\1466146022853916557.json
# Contain giveaway caption found in: ../../dataset/json\1469760254920971571.json
# Contain giveaway caption found in: ../../dataset/json\1508800525092393668.json
# Contain giveaway caption found in: ../../dataset/json\1513153274026150835.json
# Contain giveaway caption found in: ../../dataset/json\1514598303382962525.json
# Contain giveaway caption found in: ../../dataset/json\1592910399883132659.json
# Contain giveaway caption found in: ../../dataset/json\1593634777247637141.json
# Contain giveaway caption found in: ../../dataset/json\1595816295810298957.json
# Contain giveaway caption found in: ../../dataset/json\1618336452336035590.json
# Contain giveaway caption found in: ../../dataset/json\1621858015777654318.json
# Contain giveaway caption found in: ../../dataset/json\1625562150930756873.json
# Contain giveaway caption found in: ../../dataset/json\1969066290626917042.json
# Contain giveaway caption found in: ../../dataset/json\1888571901463445123.json
# Contain giveaway caption found in: ../../dataset/json\1634271481680586729.json
# Contain giveaway caption found in: ../../dataset/json\1635994728641946927.json
# Contain giveaway caption found in: ../../dataset/json\1927763206575684210.json
# Contain giveaway caption found in: ../../dataset/json\1973679093748611273.json
# Contain giveaway caption found in: ../../dataset/json\1882661481506621971.json

# %%
def count_total_posts_with_no_contain_giveaway_caption(file_path=contain_giveaway_caption_posts_path):
    return count_posts(file_path)

# %%
total_posts_with_no_contain_giveaway_caption = count_total_posts_with_no_contain_giveaway_caption(
    contain_giveaway_caption_posts_path
)
print(f"Total posts with no contain giveaway caption: {total_posts_with_no_contain_giveaway_caption}")
# Out:
# Total posts with no contain giveaway caption: 28180

# %% [markdown]
# ##### Create new **post info txt** file with no missing image(s), json, caption, non-English caption, and contain giveaway caption

# %%
def create_no_missing_data_and_no_non_english_caption_and_no_contain_giveaway_caption_post_info_file(post_with_existing_images_json_caption_and_english_info_path, contain_giveaway_caption_posts_path, post_clean_info_path):
    with open(contain_giveaway_caption_posts_path, "r", encoding="utf-8") as f_missing:
        contain_giveaway_posts = set(line.strip() for line in f_missing)

    with open(post_with_existing_images_json_caption_and_english_info_path, "r", encoding="utf-8") as f_in, \
            open(post_clean_info_path, "w", encoding="utf-8") as f_out:

        row_number = 0
        for line in f_in:
            if line.strip() and line.strip() not in contain_giveaway_posts:
                f_out.write(str(row_number) + line[line.find('\t'):])
                row_number += 1

# %%
create_no_missing_data_and_no_non_english_caption_and_no_contain_giveaway_caption_post_info_file(post_with_existing_images_json_caption_and_english_info_path, contain_giveaway_caption_posts_path, post_clean_info_path)

# %% [markdown]
# ##### Total posts **(after removing posts with missing image(s), json, caption, non-English caption, and contain giveaway caption)**

# %%
def count_post_with_no_missing_data_and_no_non_english_caption_and_no_contain_giveaway_caption(file_path=post_clean_info_path):
    return count_posts(file_path)

# %%
total_posts_with_no_missing_data_and_no_non_english_caption_and_no_contain_giveaway_caption = count_post_with_no_missing_data_and_no_non_english_caption_and_no_contain_giveaway_caption(
    post_clean_info_path
)
print(f"Total posts with no missing data, non-English caption, and not contain giveaway caption: {total_posts_with_no_missing_data_and_no_non_english_caption_and_no_contain_giveaway_caption}")
# Out:
# Total posts with no missing data, non-English caption, and not contain giveaway caption: 1325529

# %% [markdown]
# ##### Create influencer list file

# %%
def create_influencer_list(clean_data_path, profiles_dir, output_csv_path, error_list_path):
    # Create/open CSV file with header
    with open(output_csv_path, 'w', encoding='utf-8') as csv_file:
        csv_file.write('influencer_name,followers,followees,posts,category\n')
    
    # Create/open error list file
    with open(error_list_path, 'w', encoding='utf-8') as error_file:
        pass
    
    # Track processed influencers to avoid duplicates
    processed_influencers = set()
    
    # Process clean data file line by line
    with open(clean_data_path, 'r', encoding='utf-8') as f:
        for index, line in enumerate(f):
            if not line.strip():
                continue
                
            # Extract influencer name (second element after splitting)
            parts = line.strip().split('\t')
            if len(parts) < 2:
                continue
                
            influencer_name = parts[1]
            
            # Skip if already processed
            if influencer_name in processed_influencers:
                continue
                
            processed_influencers.add(influencer_name)
            
            # Try to read influencer profile
            profile_path = os.path.join(profiles_dir, influencer_name)
            try:
                with open(profile_path, 'r', encoding='utf-8') as profile_file:
                    profile_data = profile_file.readline().strip().split('\t')
                    
                    # Extract required fields (followers, followees, posts, category)
                    followers = profile_data[1] if len(profile_data) > 1 else 'NULL'
                    followees = profile_data[2] if len(profile_data) > 2 else 'NULL'
                    posts = profile_data[3] if len(profile_data) > 3 else 'NULL'
                    category = profile_data[6] if len(profile_data) > 6 else 'NULL'
                    
                    # Write to CSV
                    with open(output_csv_path, 'a', encoding='utf-8') as csv_file:
                        csv_file.write(f'{influencer_name},{followers},{followees},{posts},{category}\n')
                        csv_file.flush()
                        
            except (FileNotFoundError, IndexError, Exception) as e:
                # Log error and continue
                with open(error_list_path, 'a', encoding='utf-8') as error_file:
                    error_file.write(f'{index}\t{influencer_name}\n')
                    error_file.flush()
                
                # Still write to CSV with NULL values
                with open(output_csv_path, 'a', encoding='utf-8') as csv_file:
                    csv_file.write(f'{influencer_name},NULL,NULL,NULL,NULL\n')
                    csv_file.flush()

# %%
create_influencer_list(
    post_clean_info_path,
    profiles_influencers_dir,
    influencers_list_clean_path,
    influencers_error_list_path
)

# %% [markdown]
# ## Data Exploration

# %% [markdown]
# ##### Exploration

# %%
def apply_chart_styling(ax, title, xlabel, ylabel, rotation=0, y_margin_top=0.15):
    """
    Apply consistent styling to charts with larger fonts and proper spacing.
    
    Parameters:
    ax: matplotlib axis object
    title (str): Chart title
    xlabel (str): X-axis label
    ylabel (str): Y-axis label
    rotation (int): X-axis tick rotation angle, default 45
    y_margin_top (float): Additional margin at top as fraction of max y value
    """
    plt.title(title, fontweight='bold', pad=20, fontsize=16)
    plt.xlabel(xlabel, fontsize=16, labelpad=15)
    plt.ylabel(ylabel, fontsize=16, labelpad=15)
    plt.xticks(rotation=rotation, fontsize=16)
    plt.yticks(fontsize=16)
    
    # Add spacing for axis labels
    ax.tick_params(axis='y', pad=10)
    ax.tick_params(axis='x', pad=10)
    
    # Adjust y-axis limits to provide space for bar labels
    y_min, y_max = ax.get_ylim()
    ax.set_ylim(y_min, y_max * (1 + y_margin_top))

def add_bar_labels(ax, values, spacing_factor=0.05, fontsize=14):
    """
    Add count labels on top of bars with consistent formatting.
    
    Parameters:
    ax: matplotlib axis object
    values: array of values to display
    spacing_factor (float): Space above bars as fraction of max value
    fontsize (int): Font size for labels
    """
    for i, v in enumerate(values):
        # Format large numbers with points instead of commas if needed
        label = f'{v:,.0f}'.replace(',', '.') if v >= 1000 else str(v)
        ax.text(i, v + max(values) * spacing_factor, label,
                ha='center', va='bottom', fontweight='bold', fontsize=fontsize)

def explore_influencer_data(exploration_data_dir, influencers_list_path, post_data_path):
    """
    Explore influencer data and generate statistics and visualizations.
    
    Parameters:
    exploration_data_dir (str): Directory to save exploration results
    influencers_list_path (str): Path to the influencers CSV file
    post_data_path (str): Path to the post data file
    """
    # Create exploration_data_dir if it doesn't exist
    if not os.path.exists(exploration_data_dir):
        os.makedirs(exploration_data_dir)
        
    # Read the influencers CSV
    df = pd.read_csv(influencers_list_path)
    
    # Convert numeric columns
    numeric_columns = ['followers', 'followees', 'posts']
    for col in numeric_columns:
        df[col] = pd.to_numeric(df[col].replace('NULL', pd.NA), errors='coerce')
    
    # Basic statistics
    stats = df[numeric_columns].describe()
    stats.to_csv(os.path.join(exploration_data_dir, 'influencer_statistics.csv'))
    
    # Create more granular follower ranges
    follower_ranges = [0, 10000, 50000, 100000, 150000, 200000, 250000, 300000]
    range_labels = ['<10K', '10K-50K', '50K-100K', '100K-150K', '150K-200K', 
                   '200K-250K', '250K-300K']
    
    df['follower_range'] = pd.cut(df['followers'], 
                                 bins=follower_ranges, 
                                 labels=range_labels,
                                 ordered=True)
    
    # Get value counts in the specific order
    follower_dist = df['follower_range'].value_counts().reindex(range_labels)
    
    # Plot follower range distribution
    plt.figure(figsize=(15, 6))
    ax = follower_dist.plot(kind='bar')
    apply_chart_styling(ax, 
                       'Distribusi Jumlah Influencer Berdasarkan Jangkauan Jumlah Follower',
                       'Jangkauan Jumlah Follower', 
                       'Jumlah Influencer')
    add_bar_labels(ax, follower_dist.values)
    
    plt.tight_layout()
    plt.savefig(os.path.join(exploration_data_dir, 'follower_range_distribution.png'))
    plt.close()
    
    # Category distribution
    plt.figure(figsize=(12, 6))
    category_counts = df['category'].value_counts()
    ax = category_counts.plot(kind='bar')
    plt.title('Distribution of Influencer Categories')
    plt.xlabel('Category')
    plt.ylabel('Number of Influencers')
    plt.xticks(rotation=45)
    
    # Add count labels on top of each bar
    for i, v in enumerate(category_counts.values):
        ax.text(i, v + max(category_counts.values) * 0.01, str(v), 
                ha='center', va='bottom', fontweight='bold')
    
    plt.tight_layout()
    plt.savefig(os.path.join(exploration_data_dir, 'category_distribution.png'))
    plt.close()
    
    # Correlation matrix
    plt.figure(figsize=(8, 6))
    sns.heatmap(df[numeric_columns].corr(), annot=True, cmap='coolwarm')
    plt.title('Correlation Matrix of Numeric Variables')
    plt.tight_layout()
    plt.savefig(os.path.join(exploration_data_dir, 'correlation_matrix.png'))
    plt.close()
    
    # Create dictionary to store post counts per influencer
    influencer_post_counts = {}
    
    # Read and count posts from the clean data file
    with open(post_data_path, 'r', encoding='utf-8') as f:
        for line in f:
            parts = line.strip().split('\t')
            if len(parts) >= 2:
                influencer_name = parts[1]
                if influencer_name in influencer_post_counts:
                    influencer_post_counts[influencer_name] += 1
                else:
                    influencer_post_counts[influencer_name] = 1
    
    # Add post counts to dataframe
    df['actual_posts'] = df['influencer_name'].map(influencer_post_counts)
    df['actual_posts'] = df['actual_posts'].fillna(0).astype(int)
    
    # Calculate total posts for each follower range using actual posts
    follower_range_posts = df.groupby('follower_range')['actual_posts'].sum().reindex(range_labels)
    
    # Plot follower range posts distribution
    plt.figure(figsize=(15, 6))
    ax = follower_range_posts.plot(kind='bar')
    apply_chart_styling(ax,
                       'Distribusi Jumlah Post Berdasarkan Jangkauan Follower',
                       'Jangkauan Follower',
                       'Jumlah Post')
    add_bar_labels(ax, follower_range_posts.values)
    
    plt.tight_layout()
    plt.savefig(os.path.join(exploration_data_dir, 'follower_range_posts_distribution.png'))
    plt.close()
    
    # Save summary to text file
    with open(os.path.join(exploration_data_dir, 'summary.txt'), 'w') as f:
        f.write("Influencer Data Summary\n")
        f.write("======================\n\n")
        f.write(f"Total number of influencers: {len(df)}\n")
        f.write(f"Number of unique categories: {df['category'].nunique()}\n\n")
        
        f.write("Detailed Statistics\n")
        f.write("-----------------\n\n")
        
        # Detailed statistics for followers
        f.write("Followers Statistics:\n")
        f.write(f"Mean: {df['followers'].mean():,.2f}\n")
        f.write(f"Std: {df['followers'].std():,.2f}\n")
        f.write(f"Min: {df['followers'].min():,.0f}\n")
        f.write(f"25%: {df['followers'].quantile(0.25):,.0f}\n")
        f.write(f"50% (Median): {df['followers'].quantile(0.5):,.0f}\n")
        f.write(f"75%: {df['followers'].quantile(0.75):,.0f}\n")
        f.write(f"Max: {df['followers'].max():,.0f}\n\n")
        
        # Detailed statistics for followees
        f.write("Followees Statistics:\n")
        f.write(f"Mean: {df['followees'].mean():,.2f}\n")
        f.write(f"Std: {df['followees'].std():,.2f}\n")
        f.write(f"Min: {df['followees'].min():,.0f}\n")
        f.write(f"25%: {df['followees'].quantile(0.25):,.0f}\n")
        f.write(f"50% (Median): {df['followees'].quantile(0.5):,.0f}\n")
        f.write(f"75%: {df['followees'].quantile(0.75):,.0f}\n")
        f.write(f"Max: {df['followees'].max():,.0f}\n\n")
        
        # Detailed statistics for posts
        f.write("Posts Statistics:\n")
        f.write(f"Mean: {df['posts'].mean():,.2f}\n")
        f.write(f"Std: {df['posts'].std():,.2f}\n")
        f.write(f"Min: {df['posts'].min():,.0f}\n")
        f.write(f"25%: {df['posts'].quantile(0.25):,.0f}\n")
        f.write(f"50% (Median): {df['posts'].quantile(0.5):,.0f}\n")
        f.write(f"75%: {df['posts'].quantile(0.75):,.0f}\n")
        f.write(f"Max: {df['posts'].max():,.0f}\n\n")
        
        f.write("\nFollower Range Distribution:\n")
        f.write(follower_dist.to_string())
        
        f.write("\n\nFollower Range Posts Distribution:\n")
        f.write("Total posts for each follower range:\n")
        f.write(follower_range_posts.to_string())
        
        f.write("\n\nCategory Distribution:\n")
        f.write(df['category'].value_counts().to_string())
        
        f.write("\nPost Distribution by Follower Range:\n")
        f.write("---------------------------------\n")
        for range_label in range_labels:
            total_posts = follower_range_posts[range_label]
            influencers = len(df[df['follower_range'] == range_label])
            f.write(f"{range_label}:\n")
            f.write(f"  Total Posts: {total_posts:,.0f}\n")
            f.write(f"  Number of Influencers: {influencers}\n")
            f.write(f"  Average Posts per Influencer: {total_posts/influencers if influencers > 0 else 0:,.1f}\n\n")
        
        f.write(f"\nTotal Posts Across All Ranges: {follower_range_posts.sum():,.0f}\n")
        f.write(f"Total Influencers: {len(df):,.0f}\n")
        f.write(f"Overall Average Posts per Influencer: {follower_range_posts.sum()/len(df):,.1f}\n")

# %%
explore_influencer_data(
    exploration_data_dir=exploration_data_clean_banget_dir,
    influencers_list_path=influencers_list_clean_path, 
    post_data_path=post_clean_info_path
)
# Out:
# C:\Users\Vito\AppData\Local\Temp\ipykernel_13008\1954221089.py:139: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   follower_range_posts = df.groupby('follower_range')['actual_posts'].sum().reindex(range_labels)

# %% [markdown]
# ## Data Preprocessing After Exploration

# %% [markdown]
# ##### Create new **post info csv** file with micro influencer only

# %%
def create_micro_influencer_post_info_file(influencers_list_path, post_with_existing_images_json_caption_and_english_info_path, post_with_micro_influencer_info_path):
    
    # Define micro influencer follower bounds
    micro_lower = 10000
    micro_upper = 100000

    # Read the influencer list and convert followers to numeric
    influencers_df = pd.read_csv(influencers_list_path)
    influencers_df['followers'] = pd.to_numeric(influencers_df['followers'].replace('NULL', pd.NA), errors='coerce')

    # Create a set of micro influencer names
    micro_influencers = set(
        influencers_df[(influencers_df['followers'] >= micro_lower) & (influencers_df['followers'] < micro_upper)]['influencer_name']
    )

    # Open the source post info text file and the destination CSV file.
    with open(post_with_existing_images_json_caption_and_english_info_path, 'r', encoding='utf-8') as fin, \
         open(post_with_micro_influencer_info_path, 'w', encoding='utf-8') as fout:
        
        row_number = 0
        # Optionally, you can add a header if needed. For now we're writing rows as filtered.
        for line in fin:
            line = line.strip()
            if not line:
                continue

            # Expecting each line to be in the format: row_number<TAB>influencer_name<TAB>...
            parts = line.split('\t')
            if len(parts) < 2:
                continue

            influencer_name = parts[1]
            if influencer_name in micro_influencers:
                # Write the filtered post info with a new row number.
                fout.write(str(row_number) + line[line.find('\t'):] + "\n")
                row_number += 1

# %%
create_micro_influencer_post_info_file(
    influencers_list_clean_path,
    post_clean_info_path,
    post_with_micro_influencer_clean_info_path
)

# %% [markdown]
# ##### Sampling

# %%
def create_stratified_sample(input_path, output_path, target_size):
    # Read influencer data
    influencers_df = pd.read_csv(influencers_list_path)
    influencers_df['followers'] = pd.to_numeric(influencers_df['followers'].replace('NULL', pd.NA), errors='coerce')
    
    # Create follower range groups
    micro_influencers = {}
    micro_influencers['10K-50K'] = set(
        influencers_df[
            (influencers_df['followers'] >= 10000) & 
            (influencers_df['followers'] < 50000)
        ]['influencer_name']
    )
    micro_influencers['50K-100K'] = set(
        influencers_df[
            (influencers_df['followers'] >= 50000) & 
            (influencers_df['followers'] < 100000)
        ]['influencer_name']
    )
    
    # Calculate target sizes for each stratum
    stratum_sizes = {
        '10K-50K': int(target_size * 0.766),  # 76.6% of posts
        '50K-100K': int(target_size * 0.234)   # 23.4% of posts
    }
    
    # Store posts by stratum
    posts_by_stratum = {'10K-50K': [], '50K-100K': []}
    
    # First pass: categorize posts by stratum
    with open(input_path, 'r', encoding='utf-8') as f:
        for line in f:
            parts = line.strip().split('\t')
            if len(parts) < 2:
                continue
                
            influencer_name = parts[1]
            if influencer_name in micro_influencers['10K-50K']:
                posts_by_stratum['10K-50K'].append(line)
            elif influencer_name in micro_influencers['50K-100K']:
                posts_by_stratum['50K-100K'].append(line)
    
    # Random sampling within each stratum
    sampled_posts = []
    for stratum, target in stratum_sizes.items():
        if posts_by_stratum[stratum]:
            # Ensure we don't try to sample more posts than available
            actual_sample_size = min(target, len(posts_by_stratum[stratum]))
            stratum_sample = random.sample(posts_by_stratum[stratum], actual_sample_size)
            sampled_posts.extend(stratum_sample)
    
    # Shuffle the final sample to mix posts from different strata
    random.shuffle(sampled_posts)
    
    # Write sampled posts to output file
    with open(output_path, 'w', encoding='utf-8') as f:
        for i, post in enumerate(sampled_posts):
            # Find the tab position and create new line with updated row number
            tab_pos = post.find('\t')
            new_line = str(i) + post[tab_pos:]
            f.write(new_line)

# %%
create_stratified_sample(
    post_with_micro_influencer_clean_info_path,
    post_34000_sampled_clean_info_path,
    target_size=34000
)

# %% [markdown]
# ## Data Exploration After Sampling

# %% [markdown]
# ##### Create influencer list file

# %%
def create_influencer_after_sampling_list(clean_data_path, profiles_dir, output_csv_path, error_list_path):
    # Create/open CSV file with header
    with open(output_csv_path, 'w', encoding='utf-8') as csv_file:
        csv_file.write('influencer_name,followers,followees,posts,category\n')
    
    # Create/open error list file
    with open(error_list_path, 'w', encoding='utf-8') as error_file:
        pass
    
    # Track processed influencers to avoid duplicates
    processed_influencers = set()
    
    # Process clean data file line by line
    with open(clean_data_path, 'r', encoding='utf-8') as f:
        for index, line in enumerate(f):
            if not line.strip():
                continue
                
            # Extract influencer name (second element after splitting)
            parts = line.strip().split('\t')
            if len(parts) < 2:
                continue
                
            influencer_name = parts[1]
            
            # Skip if already processed
            if influencer_name in processed_influencers:
                continue
                
            processed_influencers.add(influencer_name)
            
            # Try to read influencer profile
            profile_path = os.path.join(profiles_dir, influencer_name)
            try:
                with open(profile_path, 'r', encoding='utf-8') as profile_file:
                    profile_data = profile_file.readline().strip().split('\t')
                    
                    # Extract required fields (followers, followees, posts, category)
                    followers = profile_data[1] if len(profile_data) > 1 else 'NULL'
                    followees = profile_data[2] if len(profile_data) > 2 else 'NULL'
                    posts = profile_data[3] if len(profile_data) > 3 else 'NULL'
                    category = profile_data[6] if len(profile_data) > 6 else 'NULL'
                    
                    # Write to CSV
                    with open(output_csv_path, 'a', encoding='utf-8') as csv_file:
                        csv_file.write(f'{influencer_name},{followers},{followees},{posts},{category}\n')
                        csv_file.flush()
                        
            except (FileNotFoundError, IndexError, Exception) as e:
                # Log error and continue
                with open(error_list_path, 'a', encoding='utf-8') as error_file:
                    error_file.write(f'{index}\t{influencer_name}\n')
                    error_file.flush()
                
                # Still write to CSV with NULL values
                with open(output_csv_path, 'a', encoding='utf-8') as csv_file:
                    csv_file.write(f'{influencer_name},NULL,NULL,NULL,NULL\n')
                    csv_file.flush()

# %%
create_influencer_after_sampling_list(
    post_34000_sampled_clean_info_path,
    profiles_influencers_dir,
    influencers_34000_after_sampling_list_clean_path,
    influencers_error_list_path
)

# %% [markdown]
# ##### Exploration

# %%
def apply_chart_styling(ax, title, xlabel, ylabel, rotation=0, y_margin_top=0.15):
    """
    Apply consistent styling to charts with larger fonts and proper spacing.
    
    Parameters:
    ax: matplotlib axis object
    title (str): Chart title
    xlabel (str): X-axis label
    ylabel (str): Y-axis label
    rotation (int): X-axis tick rotation angle, default 45
    y_margin_top (float): Additional margin at top as fraction of max y value
    """
    plt.title(title, fontweight='bold', pad=20, fontsize=16)
    plt.xlabel(xlabel, fontsize=16, labelpad=15)
    plt.ylabel(ylabel, fontsize=16, labelpad=15)
    plt.xticks(rotation=rotation, fontsize=16)
    plt.yticks(fontsize=16)
    
    # Add spacing for axis labels
    ax.tick_params(axis='y', pad=10)
    ax.tick_params(axis='x', pad=10)
    
    # Adjust y-axis limits to provide space for bar labels
    y_min, y_max = ax.get_ylim()
    ax.set_ylim(y_min, y_max * (1 + y_margin_top))

def add_bar_labels(ax, values, spacing_factor=0.05, fontsize=14):
    """
    Add count labels on top of bars with consistent formatting.
    
    Parameters:
    ax: matplotlib axis object
    values: array of values to display
    spacing_factor (float): Space above bars as fraction of max value
    fontsize (int): Font size for labels
    """
    for i, v in enumerate(values):
        # Format large numbers with points instead of commas if needed
        label = f'{v:,.0f}'.replace(',', '.') if v >= 1000 else str(v)
        ax.text(i, v + max(values) * spacing_factor, label,
                ha='center', va='bottom', fontweight='bold', fontsize=fontsize)

def explore_influencer_data(exploration_data_dir, influencers_list_path, post_data_path):
    """
    Explore influencer data and generate statistics and visualizations.
    
    Parameters:
    exploration_data_dir (str): Directory to save exploration results
    influencers_list_path (str): Path to the influencers CSV file
    post_data_path (str): Path to the post data file
    """
    # Create exploration_data_dir if it doesn't exist
    if not os.path.exists(exploration_data_dir):
        os.makedirs(exploration_data_dir)
        
    # Read the influencers CSV
    df = pd.read_csv(influencers_list_path)
    
    # Convert numeric columns
    numeric_columns = ['followers', 'followees', 'posts']
    for col in numeric_columns:
        df[col] = pd.to_numeric(df[col].replace('NULL', pd.NA), errors='coerce')
    
    # Basic statistics
    stats = df[numeric_columns].describe()
    stats.to_csv(os.path.join(exploration_data_dir, 'influencer_statistics.csv'))
    
    # Create more granular follower ranges
    follower_ranges = [0, 10000, 50000, 100000, 150000, 200000, 250000, 300000]
    range_labels = ['<10K', '10K-50K', '50K-100K', '100K-150K', '150K-200K', 
                   '200K-250K', '250K-300K']
    
    df['follower_range'] = pd.cut(df['followers'], 
                                 bins=follower_ranges, 
                                 labels=range_labels,
                                 ordered=True)
    
    # Get value counts in the specific order
    follower_dist = df['follower_range'].value_counts().reindex(range_labels)
    
    # Plot follower range distribution
    plt.figure(figsize=(15, 6))
    ax = follower_dist.plot(kind='bar')
    apply_chart_styling(ax, 
                       'Distribusi Jumlah Influencer Berdasarkan Jangkauan Jumlah Follower',
                       'Jangkauan Jumlah Follower', 
                       'Jumlah Influencer')
    add_bar_labels(ax, follower_dist.values)
    
    plt.tight_layout()
    plt.savefig(os.path.join(exploration_data_dir, 'follower_range_distribution.png'))
    plt.close()
    
    # Category distribution
    plt.figure(figsize=(12, 6))
    category_counts = df['category'].value_counts()
    ax = category_counts.plot(kind='bar')
    plt.title('Distribution of Influencer Categories')
    plt.xlabel('Category')
    plt.ylabel('Number of Influencers')
    plt.xticks(rotation=45)
    
    # Add count labels on top of each bar
    for i, v in enumerate(category_counts.values):
        ax.text(i, v + max(category_counts.values) * 0.01, str(v), 
                ha='center', va='bottom', fontweight='bold')
    
    plt.tight_layout()
    plt.savefig(os.path.join(exploration_data_dir, 'category_distribution.png'))
    plt.close()
    
    # Correlation matrix
    plt.figure(figsize=(8, 6))
    sns.heatmap(df[numeric_columns].corr(), annot=True, cmap='coolwarm')
    plt.title('Correlation Matrix of Numeric Variables')
    plt.tight_layout()
    plt.savefig(os.path.join(exploration_data_dir, 'correlation_matrix.png'))
    plt.close()
    
    # Create dictionary to store post counts per influencer
    influencer_post_counts = {}
    
    # Read and count posts from the clean data file
    with open(post_data_path, 'r', encoding='utf-8') as f:
        for line in f:
            parts = line.strip().split('\t')
            if len(parts) >= 2:
                influencer_name = parts[1]
                if influencer_name in influencer_post_counts:
                    influencer_post_counts[influencer_name] += 1
                else:
                    influencer_post_counts[influencer_name] = 1
    
    # Add post counts to dataframe
    df['actual_posts'] = df['influencer_name'].map(influencer_post_counts)
    df['actual_posts'] = df['actual_posts'].fillna(0).astype(int)
    
    # Calculate total posts for each follower range using actual posts
    follower_range_posts = df.groupby('follower_range')['actual_posts'].sum().reindex(range_labels)
    
    # Plot follower range posts distribution
    plt.figure(figsize=(15, 6))
    ax = follower_range_posts.plot(kind='bar')
    apply_chart_styling(ax,
                       'Distribusi Jumlah Post Berdasarkan Jangkauan Follower',
                       'Jangkauan Follower',
                       'Jumlah Post')
    add_bar_labels(ax, follower_range_posts.values)
    
    plt.tight_layout()
    plt.savefig(os.path.join(exploration_data_dir, 'follower_range_posts_distribution.png'))
    plt.close()
    
    # Save summary to text file
    with open(os.path.join(exploration_data_dir, 'summary.txt'), 'w') as f:
        f.write("Influencer Data Summary\n")
        f.write("======================\n\n")
        f.write(f"Total number of influencers: {len(df)}\n")
        f.write(f"Number of unique categories: {df['category'].nunique()}\n\n")
        
        f.write("Detailed Statistics\n")
        f.write("-----------------\n\n")
        
        # Detailed statistics for followers
        f.write("Followers Statistics:\n")
        f.write(f"Mean: {df['followers'].mean():,.2f}\n")
        f.write(f"Std: {df['followers'].std():,.2f}\n")
        f.write(f"Min: {df['followers'].min():,.0f}\n")
        f.write(f"25%: {df['followers'].quantile(0.25):,.0f}\n")
        f.write(f"50% (Median): {df['followers'].quantile(0.5):,.0f}\n")
        f.write(f"75%: {df['followers'].quantile(0.75):,.0f}\n")
        f.write(f"Max: {df['followers'].max():,.0f}\n\n")
        
        # Detailed statistics for followees
        f.write("Followees Statistics:\n")
        f.write(f"Mean: {df['followees'].mean():,.2f}\n")
        f.write(f"Std: {df['followees'].std():,.2f}\n")
        f.write(f"Min: {df['followees'].min():,.0f}\n")
        f.write(f"25%: {df['followees'].quantile(0.25):,.0f}\n")
        f.write(f"50% (Median): {df['followees'].quantile(0.5):,.0f}\n")
        f.write(f"75%: {df['followees'].quantile(0.75):,.0f}\n")
        f.write(f"Max: {df['followees'].max():,.0f}\n\n")
        
        # Detailed statistics for posts
        f.write("Posts Statistics:\n")
        f.write(f"Mean: {df['posts'].mean():,.2f}\n")
        f.write(f"Std: {df['posts'].std():,.2f}\n")
        f.write(f"Min: {df['posts'].min():,.0f}\n")
        f.write(f"25%: {df['posts'].quantile(0.25):,.0f}\n")
        f.write(f"50% (Median): {df['posts'].quantile(0.5):,.0f}\n")
        f.write(f"75%: {df['posts'].quantile(0.75):,.0f}\n")
        f.write(f"Max: {df['posts'].max():,.0f}\n\n")
        
        f.write("\nFollower Range Distribution:\n")
        f.write(follower_dist.to_string())
        
        f.write("\n\nFollower Range Posts Distribution:\n")
        f.write("Total posts for each follower range:\n")
        f.write(follower_range_posts.to_string())
        
        f.write("\n\nCategory Distribution:\n")
        f.write(df['category'].value_counts().to_string())
        
        f.write("\nPost Distribution by Follower Range:\n")
        f.write("---------------------------------\n")
        for range_label in range_labels:
            total_posts = follower_range_posts[range_label]
            influencers = len(df[df['follower_range'] == range_label])
            f.write(f"{range_label}:\n")
            f.write(f"  Total Posts: {total_posts:,.0f}\n")
            f.write(f"  Number of Influencers: {influencers}\n")
            f.write(f"  Average Posts per Influencer: {total_posts/influencers if influencers > 0 else 0:,.1f}\n\n")
        
        f.write(f"\nTotal Posts Across All Ranges: {follower_range_posts.sum():,.0f}\n")
        f.write(f"Total Influencers: {len(df):,.0f}\n")
        f.write(f"Overall Average Posts per Influencer: {follower_range_posts.sum()/len(df):,.1f}\n")

# %%
explore_influencer_data(
    exploration_34000_data_after_sampling_clean_dir,
    influencers_34000_after_sampling_list_clean_path,
    post_34000_sampled_clean_info_path
)
# Out:
# C:\Users\Vito\AppData\Local\Temp\ipykernel_15232\1954221089.py:139: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   follower_range_posts = df.groupby('follower_range')['actual_posts'].sum().reindex(range_labels)
